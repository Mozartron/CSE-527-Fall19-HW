# %% [markdown]
# # CSE527 Homework 6
# **Due date: 23:59 on Dec. 5, 2019 (Thursday)**
#
# In this semester, we will use Google Colab for the assignments, which allows us to utilize resources that some of us might not have in their local machines such as GPUs. You will need to use your Stony Brook (*.stonybrook.edu) account for coding and Google Drive to save your results.
#
# ## Google Colab Tutorial
# ---
# Go to https://colab.research.google.com/notebooks/, you will see a tutorial named "Welcome to Colaboratory" file, where you can learn the basics of using google colab.
#
# Settings used for assignments: ***Edit -> Notebook Settings -> Runtime Type (Python 3)***.
#
#
# ## Description
# ---
# In this homework we are going to work on estimating the 3D pose of a person given their 2D
# pose. Turns out, just regressing the 3D pose coordinates using the 2D pose works pretty well [1]
# (you can find the paper [here](https://arxiv.org/pdf/1705.03098.pdf)). In Part One, we are going to work on reproducing the results of the
# paper, in Part Two, we are going to try to find a way to handle noisy measurement.
#
# ## Some Tutorials (PyTorch)
# ---
# - You will be using PyTorch for deep learning toolbox (follow the [link](http://pytorch.org) for installation).
# - For PyTorch beginners, please read this [tutorial](http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) before doing your homework.
# - Feel free to study more tutorials at http://pytorch.org/tutorials/.
# - Find cool visualization here at http://playground.tensorflow.org.
#
#
# ## Starter Code
# ---
# In the starter code, you are provided with a function that loads data into minibatches for training and testing in PyTorch.
#
# ## Benchmark
# Train for a least 30 epochs to get a least 44mm avg error. The test result(mm error) should be in the following sequence **direct.	discuss.	eat.	greet.	phone	photo	pose	purch.	sit	sitd.	somke	wait	walkd.	walk	walkT	avg**

# %% [markdown]
# ## Problem 1:
# {60 points} Let us first start by trying to reproduce the testing accuracy obtained by in the [paper]((https://arxiv.org/pdf/1705.03098.pdf) above using
# PyTorch. The 2D pose of a person is represented as a set of 2D coordinates for each of their $n = 32$ joints
# i.e $P^{2D}_{i }$= {$(x^{1}_{i}, y^{1}_{i}), ...,(x^{32}_{i}, y^{32}_{i})$}, where $(x^{j}_{i}, y^{j}_{i})$ are the 2D coordinates of the $j$’th joint of the i’th sample. Similarly, the 3D pose of a person is
# $P^{3D}_{i}$ = {$(x^{1}_{i}, y^{1}_{i}, z^{1}_{i}), ...,(x^{32}_{i}, y^{32}_{i}, z^{32}_{i})$},
# where $(x^{j}_{i}, y^{j}_{i}, z^{j}_{i})$ are the 3D coordinates of the $j$’th joint of the $i$’th sample. The only data given to you is the ground
# truth 3D pose and the 2D pose calculated using the camera parameters.
# You are going to train a network $f_{θ} : R^{2n} → R^{3n}$ that takes as input the $P^{2D}_{i}$ and tries to regress the ground truth 3D pose $P^{3D}_{i}$. The loss function to train this network would be the $L2$ loss between the ground truth and the predicted pose
# \begin{equation*}
# L(\theta) = \sum^{M}_{i=1}(P^{3D}_{i} - f_{\theta}(P^{2D}_{i}))^{2} ;\;\;\;\;\;\;\;\; \text{for a minibatch of size M} \;\;\;\;\;\;\;\; (2)
# \end{equation*}
#
# Download the Human3.6M Dataset [here](https://www.dropbox.com/s/e35qv3n6zlkouki/h36m.zip).
#
# **Bonus**: Every 1mm drop in test error from 44mm till 40mm gets you 2 extra points, and every 1mm drop below 40mm gets you 4 extra points.

# %%
# Mount your google drive where you've saved your assignment folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Set your working directory (in your google drive), '/content/gdrive/My Drive/CSE-527-Intro-To-Computer-Vision/hw06/src' is just an example, 
#   change it to your specific homework directory and src.
# Note that Surname_Givenname_SBUID_hw6.ipynb is in the same level of the folder src.

# The structure is like
# Surname_Givenname_SBUID_hw6
#        |---Surname_Givenname_SBUID_hw6.ipynb
#        |---src/*
cd '/content/gdrive/My Drive/Ramajayam_Gautham_112965275_hw6/src'
# Out:
# /content/gdrive/My Drive/Ramajayam_Gautham_112965275_hw6/src

# %%
pip install pykalman
# Out:
# Collecting pykalman
#   Downloading https://files.pythonhosted.org/packages/2f/62/a4adc4516bd5974aa5583090199dd4b78d1e87018d14e9279f72ccbf0b9b/pykalman-0.9.5.tar.gz (228kB)
#      |████████████████████████████████| 235kB 7.0MB/s
# Building wheels for collected packages: pykalman
#   Building wheel for pykalman (setup.py) ... done
#   Created wheel for pykalman: filename=pykalman-0.9.5-cp36-none-any.whl size=48464 sha256=93f389e754ec2cb563479f2d49c1613edd1e5cc8beee80087a2d439ad850599f
#   Stored in directory: /root/.cache/pip/wheels/d9/e8/6a/553d9832679cb74a8434fa597c3abdb07313e40054a0adf9ac
# Successfully built pykalman
# Installing collected packages: pykalman
# Successfully installed pykalman-0.9.5

# %%
from __future__ import print_function, absolute_import, division

import os
import sys
import time
from pprint import pprint
import numpy as np

import torch
import torch.nn as nn
import torch.optim
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader
from torch.autograd import Variable

# Locate to the src folder to import the following functions.
from procrustes import get_transformation
import data_process as data_process
import data_utils
import progress.progress.bar as pBar
import utils as utils
import misc as misc
import log as log
import cameras

from pykalman import KalmanFilter
from sklearn.metrics import mean_squared_error 
import matplotlib.pyplot as plt

# %%
# Feel free to use more cells if necessary.

# %%
# Define actions
actions = data_utils.define_actions("All")

# %%
# Load camera parameters
SUBJECT_IDS = [1,5,6,7,8,9,11]
cameras_path = '../h36m/cameras.h5'
rcams = cameras.load_cameras(cameras_path, SUBJECT_IDS)

# %%
# Load data
data_dir = '../h36m/'
camera_frame = True
predict_14 = False
# Load 3d data and load (or create) 2d projections
train_set_3d, test_set_3d, data_mean_3d, data_std_3d, dim_to_ignore_3d, dim_to_use_3d, train_root_positions, test_root_positions = data_utils.read_3d_data(
    actions, data_dir, camera_frame, rcams, predict_14 )
# Out:
# Reading subject 1, action Directions
# ../h36m/S1/MyPoses/3D_positions/Directions*.h5
# ../h36m/S1/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S1/MyPoses/3D_positions/Directions.h5
# Reading subject 1, action Discussion
# ../h36m/S1/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S1/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S1/MyPoses/3D_positions/Discussion.h5
# Reading subject 1, action Eating
# ../h36m/S1/MyPoses/3D_positions/Eating*.h5
# ../h36m/S1/MyPoses/3D_positions/Eating 2.h5
# ../h36m/S1/MyPoses/3D_positions/Eating.h5
# Reading subject 1, action Greeting
# ../h36m/S1/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S1/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S1/MyPoses/3D_positions/Greeting.h5
# Reading subject 1, action Phoning
# ../h36m/S1/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S1/MyPoses/3D_positions/Phoning 1.h5
# ../h36m/S1/MyPoses/3D_positions/Phoning.h5
# Reading subject 1, action Photo
# ../h36m/S1/MyPoses/3D_positions/Photo*.h5
# ../h36m/S1/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S1/MyPoses/3D_positions/Photo.h5
# Reading subject 1, action Posing
# ../h36m/S1/MyPoses/3D_positions/Posing*.h5
# ../h36m/S1/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S1/MyPoses/3D_positions/Posing.h5
# Reading subject 1, action Purchases
# ../h36m/S1/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S1/MyPoses/3D_positions/Purchases.h5
# ../h36m/S1/MyPoses/3D_positions/Purchases 1.h5
# Reading subject 1, action Sitting
# ../h36m/S1/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S1/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S1/MyPoses/3D_positions/Sitting 2.h5
# Reading subject 1, action SittingDown
# ../h36m/S1/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S1/MyPoses/3D_positions/SittingDown 2.h5
# ../h36m/S1/MyPoses/3D_positions/SittingDown.h5
# Reading subject 1, action Smoking
# ../h36m/S1/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S1/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S1/MyPoses/3D_positions/Smoking.h5
# Reading subject 1, action Waiting
# ../h36m/S1/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S1/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S1/MyPoses/3D_positions/Waiting.h5
# Reading subject 1, action WalkDog
# ../h36m/S1/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S1/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S1/MyPoses/3D_positions/WalkDog.h5
# Reading subject 1, action Walking
# ../h36m/S1/MyPoses/3D_positions/Walking*.h5
# ../h36m/S1/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S1/MyPoses/3D_positions/Walking.h5
# Reading subject 1, action WalkTogether
# ../h36m/S1/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S1/MyPoses/3D_positions/WalkTogether.h5
# ../h36m/S1/MyPoses/3D_positions/WalkTogether 1.h5
# Reading subject 5, action Directions
# ../h36m/S5/MyPoses/3D_positions/Directions*.h5
# ../h36m/S5/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S5/MyPoses/3D_positions/Directions 2.h5
# Reading subject 5, action Discussion
# ../h36m/S5/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S5/MyPoses/3D_positions/Discussion 2.h5
# ../h36m/S5/MyPoses/3D_positions/Discussion 3.h5
# Reading subject 5, action Eating
# ../h36m/S5/MyPoses/3D_positions/Eating*.h5
# ../h36m/S5/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S5/MyPoses/3D_positions/Eating.h5
# Reading subject 5, action Greeting
# ../h36m/S5/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S5/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S5/MyPoses/3D_positions/Greeting 2.h5
# Reading subject 5, action Phoning
# ../h36m/S5/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S5/MyPoses/3D_positions/Phoning 1.h5
# ../h36m/S5/MyPoses/3D_positions/Phoning.h5
# Reading subject 5, action Photo
# ../h36m/S5/MyPoses/3D_positions/Photo*.h5
# ../h36m/S5/MyPoses/3D_positions/Photo 2.h5
# ../h36m/S5/MyPoses/3D_positions/Photo.h5
# Reading subject 5, action Posing
# ../h36m/S5/MyPoses/3D_positions/Posing*.h5
# ../h36m/S5/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S5/MyPoses/3D_positions/Posing.h5
# Reading subject 5, action Purchases
# ../h36m/S5/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S5/MyPoses/3D_positions/Purchases 1.h5
# ../h36m/S5/MyPoses/3D_positions/Purchases.h5
# Reading subject 5, action Sitting
# ../h36m/S5/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S5/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S5/MyPoses/3D_positions/Sitting.h5
# Reading subject 5, action SittingDown
# ../h36m/S5/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S5/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S5/MyPoses/3D_positions/SittingDown.h5
# Reading subject 5, action Smoking
# ../h36m/S5/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S5/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S5/MyPoses/3D_positions/Smoking.h5
# Reading subject 5, action Waiting
# ../h36m/S5/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S5/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S5/MyPoses/3D_positions/Waiting 2.h5
# Reading subject 5, action WalkDog
# ../h36m/S5/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S5/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S5/MyPoses/3D_positions/WalkDog.h5
# Reading subject 5, action Walking
# ../h36m/S5/MyPoses/3D_positions/Walking*.h5
# ../h36m/S5/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S5/MyPoses/3D_positions/Walking.h5
# Reading subject 5, action WalkTogether
# ../h36m/S5/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S5/MyPoses/3D_positions/WalkTogether 1.h5
# ../h36m/S5/MyPoses/3D_positions/WalkTogether.h5
# Reading subject 6, action Directions
# ../h36m/S6/MyPoses/3D_positions/Directions*.h5
# ../h36m/S6/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S6/MyPoses/3D_positions/Directions.h5
# Reading subject 6, action Discussion
# ../h36m/S6/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S6/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S6/MyPoses/3D_positions/Discussion.h5
# Reading subject 6, action Eating
# ../h36m/S6/MyPoses/3D_positions/Eating*.h5
# ../h36m/S6/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S6/MyPoses/3D_positions/Eating 2.h5
# Reading subject 6, action Greeting
# ../h36m/S6/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S6/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S6/MyPoses/3D_positions/Greeting.h5
# Reading subject 6, action Phoning
# ../h36m/S6/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S6/MyPoses/3D_positions/Phoning 1.h5
# ../h36m/S6/MyPoses/3D_positions/Phoning.h5
# Reading subject 6, action Photo
# ../h36m/S6/MyPoses/3D_positions/Photo*.h5
# ../h36m/S6/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S6/MyPoses/3D_positions/Photo.h5
# Reading subject 6, action Posing
# ../h36m/S6/MyPoses/3D_positions/Posing*.h5
# ../h36m/S6/MyPoses/3D_positions/Posing.h5
# ../h36m/S6/MyPoses/3D_positions/Posing 2.h5
# Reading subject 6, action Purchases
# ../h36m/S6/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S6/MyPoses/3D_positions/Purchases 1.h5
# ../h36m/S6/MyPoses/3D_positions/Purchases.h5
# Reading subject 6, action Sitting
# ../h36m/S6/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S6/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S6/MyPoses/3D_positions/Sitting 2.h5
# Reading subject 6, action SittingDown
# ../h36m/S6/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S6/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S6/MyPoses/3D_positions/SittingDown.h5
# Reading subject 6, action Smoking
# ../h36m/S6/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S6/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S6/MyPoses/3D_positions/Smoking.h5
# Reading subject 6, action Waiting
# ../h36m/S6/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S6/MyPoses/3D_positions/Waiting 3.h5
# ../h36m/S6/MyPoses/3D_positions/Waiting.h5
# Reading subject 6, action WalkDog
# ../h36m/S6/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S6/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S6/MyPoses/3D_positions/WalkDog.h5
# Reading subject 6, action Walking
# ../h36m/S6/MyPoses/3D_positions/Walking*.h5
# ../h36m/S6/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S6/MyPoses/3D_positions/Walking.h5
# Reading subject 6, action WalkTogether
# ../h36m/S6/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S6/MyPoses/3D_positions/WalkTogether 1.h5
# ../h36m/S6/MyPoses/3D_positions/WalkTogether.h5
# Reading subject 7, action Directions
# ../h36m/S7/MyPoses/3D_positions/Directions*.h5
# ../h36m/S7/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S7/MyPoses/3D_positions/Directions.h5
# Reading subject 7, action Discussion
# ../h36m/S7/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S7/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S7/MyPoses/3D_positions/Discussion.h5
# Reading subject 7, action Eating
# ../h36m/S7/MyPoses/3D_positions/Eating*.h5
# ../h36m/S7/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S7/MyPoses/3D_positions/Eating.h5
# Reading subject 7, action Greeting
# ../h36m/S7/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S7/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S7/MyPoses/3D_positions/Greeting.h5
# Reading subject 7, action Phoning
# ../h36m/S7/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S7/MyPoses/3D_positions/Phoning 2.h5
# ../h36m/S7/MyPoses/3D_positions/Phoning.h5
# Reading subject 7, action Photo
# ../h36m/S7/MyPoses/3D_positions/Photo*.h5
# ../h36m/S7/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S7/MyPoses/3D_positions/Photo.h5
# Reading subject 7, action Posing
# ../h36m/S7/MyPoses/3D_positions/Posing*.h5
# ../h36m/S7/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S7/MyPoses/3D_positions/Posing.h5
# Reading subject 7, action Purchases
# ../h36m/S7/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S7/MyPoses/3D_positions/Purchases 1.h5
# ../h36m/S7/MyPoses/3D_positions/Purchases.h5
# Reading subject 7, action Sitting
# ../h36m/S7/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S7/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S7/MyPoses/3D_positions/Sitting.h5
# Reading subject 7, action SittingDown
# ../h36m/S7/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S7/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S7/MyPoses/3D_positions/SittingDown.h5
# Reading subject 7, action Smoking
# ../h36m/S7/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S7/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S7/MyPoses/3D_positions/Smoking.h5
# Reading subject 7, action Waiting
# ../h36m/S7/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S7/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S7/MyPoses/3D_positions/Waiting 2.h5
# Reading subject 7, action WalkDog
# ../h36m/S7/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S7/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S7/MyPoses/3D_positions/WalkDog.h5
# Reading subject 7, action Walking
# ../h36m/S7/MyPoses/3D_positions/Walking*.h5
# ../h36m/S7/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S7/MyPoses/3D_positions/Walking 2.h5
# Reading subject 7, action WalkTogether
# ../h36m/S7/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S7/MyPoses/3D_positions/WalkTogether 1.h5
# ../h36m/S7/MyPoses/3D_positions/WalkTogether.h5
# Reading subject 8, action Directions
# ../h36m/S8/MyPoses/3D_positions/Directions*.h5
# ../h36m/S8/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S8/MyPoses/3D_positions/Directions.h5
# Reading subject 8, action Discussion
# ../h36m/S8/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S8/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S8/MyPoses/3D_positions/Discussion.h5
# Reading subject 8, action Eating
# ../h36m/S8/MyPoses/3D_positions/Eating*.h5
# ../h36m/S8/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S8/MyPoses/3D_positions/Eating.h5
# Reading subject 8, action Greeting
# ../h36m/S8/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S8/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S8/MyPoses/3D_positions/Greeting.h5
# Reading subject 8, action Phoning
# ../h36m/S8/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S8/MyPoses/3D_positions/Phoning 1.h5
# ../h36m/S8/MyPoses/3D_positions/Phoning.h5
# Reading subject 8, action Photo
# ../h36m/S8/MyPoses/3D_positions/Photo*.h5
# ../h36m/S8/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S8/MyPoses/3D_positions/Photo.h5
# Reading subject 8, action Posing
# ../h36m/S8/MyPoses/3D_positions/Posing*.h5
# ../h36m/S8/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S8/MyPoses/3D_positions/Posing.h5
# Reading subject 8, action Purchases
# ../h36m/S8/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S8/MyPoses/3D_positions/Purchases 1.h5
# ../h36m/S8/MyPoses/3D_positions/Purchases.h5
# Reading subject 8, action Sitting
# ../h36m/S8/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S8/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S8/MyPoses/3D_positions/Sitting.h5
# Reading subject 8, action SittingDown
# ../h36m/S8/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S8/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S8/MyPoses/3D_positions/SittingDown.h5
# Reading subject 8, action Smoking
# ../h36m/S8/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S8/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S8/MyPoses/3D_positions/Smoking.h5
# Reading subject 8, action Waiting
# ../h36m/S8/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S8/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S8/MyPoses/3D_positions/Waiting.h5
# Reading subject 8, action WalkDog
# ../h36m/S8/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S8/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S8/MyPoses/3D_positions/WalkDog.h5
# Reading subject 8, action Walking
# ../h36m/S8/MyPoses/3D_positions/Walking*.h5
# ../h36m/S8/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S8/MyPoses/3D_positions/Walking.h5
# Reading subject 8, action WalkTogether
# ../h36m/S8/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S8/MyPoses/3D_positions/WalkTogether 1.h5
# ../h36m/S8/MyPoses/3D_positions/WalkTogether 2.h5
# Reading subject 9, action Directions
# ../h36m/S9/MyPoses/3D_positions/Directions*.h5
# ../h36m/S9/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S9/MyPoses/3D_positions/Directions.h5
# Reading subject 9, action Discussion
# ../h36m/S9/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S9/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S9/MyPoses/3D_positions/Discussion 2.h5
# Reading subject 9, action Eating
# ../h36m/S9/MyPoses/3D_positions/Eating*.h5
# ../h36m/S9/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S9/MyPoses/3D_positions/Eating.h5
# Reading subject 9, action Greeting
# ../h36m/S9/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S9/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S9/MyPoses/3D_positions/Greeting.h5
# Reading subject 9, action Phoning
# ../h36m/S9/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S9/MyPoses/3D_positions/Phoning 1.h5
# ../h36m/S9/MyPoses/3D_positions/Phoning.h5
# Reading subject 9, action Photo
# ../h36m/S9/MyPoses/3D_positions/Photo*.h5
# ../h36m/S9/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S9/MyPoses/3D_positions/Photo.h5
# Reading subject 9, action Posing
# ../h36m/S9/MyPoses/3D_positions/Posing*.h5
# ../h36m/S9/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S9/MyPoses/3D_positions/Posing.h5
# Reading subject 9, action Purchases
# ../h36m/S9/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S9/MyPoses/3D_positions/Purchases.h5
# ../h36m/S9/MyPoses/3D_positions/Purchases 1.h5
# Reading subject 9, action Sitting
# ../h36m/S9/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S9/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S9/MyPoses/3D_positions/Sitting.h5
# Reading subject 9, action SittingDown
# ../h36m/S9/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S9/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S9/MyPoses/3D_positions/SittingDown.h5
# Reading subject 9, action Smoking
# ../h36m/S9/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S9/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S9/MyPoses/3D_positions/Smoking.h5
# Reading subject 9, action Waiting
# ../h36m/S9/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S9/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S9/MyPoses/3D_positions/Waiting.h5
# Reading subject 9, action WalkDog
# ../h36m/S9/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S9/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S9/MyPoses/3D_positions/WalkDog.h5
# Reading subject 9, action Walking
# ../h36m/S9/MyPoses/3D_positions/Walking*.h5
# ../h36m/S9/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S9/MyPoses/3D_positions/Walking.h5
# Reading subject 9, action WalkTogether
# ../h36m/S9/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S9/MyPoses/3D_positions/WalkTogether 1.h5
# ../h36m/S9/MyPoses/3D_positions/WalkTogether.h5
# Reading subject 11, action Directions
# ../h36m/S11/MyPoses/3D_positions/Directions*.h5
# ../h36m/S11/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S11/MyPoses/3D_positions/Directions.h5
# Reading subject 11, action Discussion
# ../h36m/S11/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S11/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S11/MyPoses/3D_positions/Discussion 2.h5
# Reading subject 11, action Eating
# ../h36m/S11/MyPoses/3D_positions/Eating*.h5
# ../h36m/S11/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S11/MyPoses/3D_positions/Eating.h5
# Reading subject 11, action Greeting
# ../h36m/S11/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S11/MyPoses/3D_positions/Greeting 2.h5
# ../h36m/S11/MyPoses/3D_positions/Greeting.h5
# Reading subject 11, action Phoning
# ../h36m/S11/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S11/MyPoses/3D_positions/Phoning 2.h5
# ../h36m/S11/MyPoses/3D_positions/Phoning 3.h5
# Reading subject 11, action Photo
# ../h36m/S11/MyPoses/3D_positions/Photo*.h5
# ../h36m/S11/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S11/MyPoses/3D_positions/Photo.h5
# Reading subject 11, action Posing
# ../h36m/S11/MyPoses/3D_positions/Posing*.h5
# ../h36m/S11/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S11/MyPoses/3D_positions/Posing.h5
# Reading subject 11, action Purchases
# ../h36m/S11/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S11/MyPoses/3D_positions/Purchases 1.h5
# ../h36m/S11/MyPoses/3D_positions/Purchases.h5
# Reading subject 11, action Sitting
# ../h36m/S11/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S11/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S11/MyPoses/3D_positions/Sitting.h5
# Reading subject 11, action SittingDown
# ../h36m/S11/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S11/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S11/MyPoses/3D_positions/SittingDown.h5
# Reading subject 11, action Smoking
# ../h36m/S11/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S11/MyPoses/3D_positions/Smoking 2.h5
# ../h36m/S11/MyPoses/3D_positions/Smoking.h5
# Reading subject 11, action Waiting
# ../h36m/S11/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S11/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S11/MyPoses/3D_positions/Waiting.h5
# Reading subject 11, action WalkDog
# ../h36m/S11/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S11/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S11/MyPoses/3D_positions/WalkDog.h5
# Reading subject 11, action Walking
# ../h36m/S11/MyPoses/3D_positions/Walking*.h5
# ../h36m/S11/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S11/MyPoses/3D_positions/Walking.h5
# Reading subject 11, action WalkTogether
# ../h36m/S11/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S11/MyPoses/3D_positions/WalkTogether.h5
# ../h36m/S11/MyPoses/3D_positions/WalkTogether 1.h5
# /content/gdrive/My Drive/Ramajayam_Gautham_112965275_hw6/src/data_utils.py:462: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   complete_train = copy.deepcopy( np.vstack( train_set.values() ))

# %%
# Read stacked hourglass 2D predictions if use_sh, otherwise use groundtruth 2D projections
use_sh = False
if use_sh:
    train_set_2d, test_set_2d, data_mean_2d, data_std_2d, dim_to_ignore_2d, dim_to_use_2d = data_utils.read_2d_predictions(actions, data_dir)
else:
    train_set_2d, test_set_2d, data_mean_2d, data_std_2d, dim_to_ignore_2d, dim_to_use_2d = data_utils.create_2d_data( actions, data_dir, rcams )
print( "done reading and normalizing data." )

stat_3d = {}
stat_3d['mean'] = data_mean_3d
stat_3d['std'] = data_std_3d
stat_3d['dim_use'] = dim_to_use_3d
# Out:
# Reading subject 1, action Directions
# ../h36m/S1/MyPoses/3D_positions/Directions*.h5
# ../h36m/S1/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S1/MyPoses/3D_positions/Directions.h5
# Reading subject 1, action Discussion
# ../h36m/S1/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S1/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S1/MyPoses/3D_positions/Discussion.h5
# Reading subject 1, action Eating
# ../h36m/S1/MyPoses/3D_positions/Eating*.h5
# ../h36m/S1/MyPoses/3D_positions/Eating 2.h5
# ../h36m/S1/MyPoses/3D_positions/Eating.h5
# Reading subject 1, action Greeting
# ../h36m/S1/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S1/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S1/MyPoses/3D_positions/Greeting.h5
# Reading subject 1, action Phoning
# ../h36m/S1/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S1/MyPoses/3D_positions/Phoning 1.h5
# ../h36m/S1/MyPoses/3D_positions/Phoning.h5
# Reading subject 1, action Photo
# ../h36m/S1/MyPoses/3D_positions/Photo*.h5
# ../h36m/S1/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S1/MyPoses/3D_positions/Photo.h5
# Reading subject 1, action Posing
# ../h36m/S1/MyPoses/3D_positions/Posing*.h5
# ../h36m/S1/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S1/MyPoses/3D_positions/Posing.h5
# Reading subject 1, action Purchases
# ../h36m/S1/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S1/MyPoses/3D_positions/Purchases.h5
# ../h36m/S1/MyPoses/3D_positions/Purchases 1.h5
# Reading subject 1, action Sitting
# ../h36m/S1/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S1/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S1/MyPoses/3D_positions/Sitting 2.h5
# Reading subject 1, action SittingDown
# ../h36m/S1/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S1/MyPoses/3D_positions/SittingDown 2.h5
# ../h36m/S1/MyPoses/3D_positions/SittingDown.h5
# Reading subject 1, action Smoking
# ../h36m/S1/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S1/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S1/MyPoses/3D_positions/Smoking.h5
# Reading subject 1, action Waiting
# ../h36m/S1/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S1/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S1/MyPoses/3D_positions/Waiting.h5
# Reading subject 1, action WalkDog
# ../h36m/S1/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S1/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S1/MyPoses/3D_positions/WalkDog.h5
# Reading subject 1, action Walking
# ../h36m/S1/MyPoses/3D_positions/Walking*.h5
# ../h36m/S1/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S1/MyPoses/3D_positions/Walking.h5
# Reading subject 1, action WalkTogether
# ../h36m/S1/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S1/MyPoses/3D_positions/WalkTogether.h5
# ../h36m/S1/MyPoses/3D_positions/WalkTogether 1.h5
# Reading subject 5, action Directions
# ../h36m/S5/MyPoses/3D_positions/Directions*.h5
# ../h36m/S5/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S5/MyPoses/3D_positions/Directions 2.h5
# Reading subject 5, action Discussion
# ../h36m/S5/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S5/MyPoses/3D_positions/Discussion 2.h5
# ../h36m/S5/MyPoses/3D_positions/Discussion 3.h5
# Reading subject 5, action Eating
# ../h36m/S5/MyPoses/3D_positions/Eating*.h5
# ../h36m/S5/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S5/MyPoses/3D_positions/Eating.h5
# Reading subject 5, action Greeting
# ../h36m/S5/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S5/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S5/MyPoses/3D_positions/Greeting 2.h5
# Reading subject 5, action Phoning
# ../h36m/S5/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S5/MyPoses/3D_positions/Phoning 1.h5
# ../h36m/S5/MyPoses/3D_positions/Phoning.h5
# Reading subject 5, action Photo
# ../h36m/S5/MyPoses/3D_positions/Photo*.h5
# ../h36m/S5/MyPoses/3D_positions/Photo 2.h5
# ../h36m/S5/MyPoses/3D_positions/Photo.h5
# Reading subject 5, action Posing
# ../h36m/S5/MyPoses/3D_positions/Posing*.h5
# ../h36m/S5/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S5/MyPoses/3D_positions/Posing.h5
# Reading subject 5, action Purchases
# ../h36m/S5/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S5/MyPoses/3D_positions/Purchases 1.h5
# ../h36m/S5/MyPoses/3D_positions/Purchases.h5
# Reading subject 5, action Sitting
# ../h36m/S5/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S5/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S5/MyPoses/3D_positions/Sitting.h5
# Reading subject 5, action SittingDown
# ../h36m/S5/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S5/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S5/MyPoses/3D_positions/SittingDown.h5
# Reading subject 5, action Smoking
# ../h36m/S5/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S5/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S5/MyPoses/3D_positions/Smoking.h5
# Reading subject 5, action Waiting
# ../h36m/S5/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S5/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S5/MyPoses/3D_positions/Waiting 2.h5
# Reading subject 5, action WalkDog
# ../h36m/S5/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S5/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S5/MyPoses/3D_positions/WalkDog.h5
# Reading subject 5, action Walking
# ../h36m/S5/MyPoses/3D_positions/Walking*.h5
# ../h36m/S5/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S5/MyPoses/3D_positions/Walking.h5
# Reading subject 5, action WalkTogether
# ../h36m/S5/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S5/MyPoses/3D_positions/WalkTogether 1.h5
# ../h36m/S5/MyPoses/3D_positions/WalkTogether.h5
# Reading subject 6, action Directions
# ../h36m/S6/MyPoses/3D_positions/Directions*.h5
# ../h36m/S6/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S6/MyPoses/3D_positions/Directions.h5
# Reading subject 6, action Discussion
# ../h36m/S6/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S6/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S6/MyPoses/3D_positions/Discussion.h5
# Reading subject 6, action Eating
# ../h36m/S6/MyPoses/3D_positions/Eating*.h5
# ../h36m/S6/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S6/MyPoses/3D_positions/Eating 2.h5
# Reading subject 6, action Greeting
# ../h36m/S6/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S6/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S6/MyPoses/3D_positions/Greeting.h5
# Reading subject 6, action Phoning
# ../h36m/S6/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S6/MyPoses/3D_positions/Phoning 1.h5
# ../h36m/S6/MyPoses/3D_positions/Phoning.h5
# Reading subject 6, action Photo
# ../h36m/S6/MyPoses/3D_positions/Photo*.h5
# ../h36m/S6/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S6/MyPoses/3D_positions/Photo.h5
# Reading subject 6, action Posing
# ../h36m/S6/MyPoses/3D_positions/Posing*.h5
# ../h36m/S6/MyPoses/3D_positions/Posing.h5
# ../h36m/S6/MyPoses/3D_positions/Posing 2.h5
# Reading subject 6, action Purchases
# ../h36m/S6/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S6/MyPoses/3D_positions/Purchases 1.h5
# ../h36m/S6/MyPoses/3D_positions/Purchases.h5
# Reading subject 6, action Sitting
# ../h36m/S6/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S6/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S6/MyPoses/3D_positions/Sitting 2.h5
# Reading subject 6, action SittingDown
# ../h36m/S6/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S6/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S6/MyPoses/3D_positions/SittingDown.h5
# Reading subject 6, action Smoking
# ../h36m/S6/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S6/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S6/MyPoses/3D_positions/Smoking.h5
# Reading subject 6, action Waiting
# ../h36m/S6/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S6/MyPoses/3D_positions/Waiting 3.h5
# ../h36m/S6/MyPoses/3D_positions/Waiting.h5
# Reading subject 6, action WalkDog
# ../h36m/S6/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S6/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S6/MyPoses/3D_positions/WalkDog.h5
# Reading subject 6, action Walking
# ../h36m/S6/MyPoses/3D_positions/Walking*.h5
# ../h36m/S6/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S6/MyPoses/3D_positions/Walking.h5
# Reading subject 6, action WalkTogether
# ../h36m/S6/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S6/MyPoses/3D_positions/WalkTogether 1.h5
# ../h36m/S6/MyPoses/3D_positions/WalkTogether.h5
# Reading subject 7, action Directions
# ../h36m/S7/MyPoses/3D_positions/Directions*.h5
# ../h36m/S7/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S7/MyPoses/3D_positions/Directions.h5
# Reading subject 7, action Discussion
# ../h36m/S7/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S7/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S7/MyPoses/3D_positions/Discussion.h5
# Reading subject 7, action Eating
# ../h36m/S7/MyPoses/3D_positions/Eating*.h5
# ../h36m/S7/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S7/MyPoses/3D_positions/Eating.h5
# Reading subject 7, action Greeting
# ../h36m/S7/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S7/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S7/MyPoses/3D_positions/Greeting.h5
# Reading subject 7, action Phoning
# ../h36m/S7/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S7/MyPoses/3D_positions/Phoning 2.h5
# ../h36m/S7/MyPoses/3D_positions/Phoning.h5
# Reading subject 7, action Photo
# ../h36m/S7/MyPoses/3D_positions/Photo*.h5
# ../h36m/S7/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S7/MyPoses/3D_positions/Photo.h5
# Reading subject 7, action Posing
# ../h36m/S7/MyPoses/3D_positions/Posing*.h5
# ../h36m/S7/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S7/MyPoses/3D_positions/Posing.h5
# Reading subject 7, action Purchases
# ../h36m/S7/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S7/MyPoses/3D_positions/Purchases 1.h5
# ../h36m/S7/MyPoses/3D_positions/Purchases.h5
# Reading subject 7, action Sitting
# ../h36m/S7/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S7/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S7/MyPoses/3D_positions/Sitting.h5
# Reading subject 7, action SittingDown
# ../h36m/S7/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S7/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S7/MyPoses/3D_positions/SittingDown.h5
# Reading subject 7, action Smoking
# ../h36m/S7/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S7/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S7/MyPoses/3D_positions/Smoking.h5
# Reading subject 7, action Waiting
# ../h36m/S7/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S7/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S7/MyPoses/3D_positions/Waiting 2.h5
# Reading subject 7, action WalkDog
# ../h36m/S7/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S7/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S7/MyPoses/3D_positions/WalkDog.h5
# Reading subject 7, action Walking
# ../h36m/S7/MyPoses/3D_positions/Walking*.h5
# ../h36m/S7/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S7/MyPoses/3D_positions/Walking 2.h5
# Reading subject 7, action WalkTogether
# ../h36m/S7/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S7/MyPoses/3D_positions/WalkTogether 1.h5
# ../h36m/S7/MyPoses/3D_positions/WalkTogether.h5
# Reading subject 8, action Directions
# ../h36m/S8/MyPoses/3D_positions/Directions*.h5
# ../h36m/S8/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S8/MyPoses/3D_positions/Directions.h5
# Reading subject 8, action Discussion
# ../h36m/S8/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S8/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S8/MyPoses/3D_positions/Discussion.h5
# Reading subject 8, action Eating
# ../h36m/S8/MyPoses/3D_positions/Eating*.h5
# ../h36m/S8/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S8/MyPoses/3D_positions/Eating.h5
# Reading subject 8, action Greeting
# ../h36m/S8/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S8/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S8/MyPoses/3D_positions/Greeting.h5
# Reading subject 8, action Phoning
# ../h36m/S8/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S8/MyPoses/3D_positions/Phoning 1.h5
# ../h36m/S8/MyPoses/3D_positions/Phoning.h5
# Reading subject 8, action Photo
# ../h36m/S8/MyPoses/3D_positions/Photo*.h5
# ../h36m/S8/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S8/MyPoses/3D_positions/Photo.h5
# Reading subject 8, action Posing
# ../h36m/S8/MyPoses/3D_positions/Posing*.h5
# ../h36m/S8/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S8/MyPoses/3D_positions/Posing.h5
# Reading subject 8, action Purchases
# ../h36m/S8/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S8/MyPoses/3D_positions/Purchases 1.h5
# ../h36m/S8/MyPoses/3D_positions/Purchases.h5
# Reading subject 8, action Sitting
# ../h36m/S8/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S8/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S8/MyPoses/3D_positions/Sitting.h5
# Reading subject 8, action SittingDown
# ../h36m/S8/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S8/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S8/MyPoses/3D_positions/SittingDown.h5
# Reading subject 8, action Smoking
# ../h36m/S8/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S8/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S8/MyPoses/3D_positions/Smoking.h5
# Reading subject 8, action Waiting
# ../h36m/S8/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S8/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S8/MyPoses/3D_positions/Waiting.h5
# Reading subject 8, action WalkDog
# ../h36m/S8/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S8/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S8/MyPoses/3D_positions/WalkDog.h5
# Reading subject 8, action Walking
# ../h36m/S8/MyPoses/3D_positions/Walking*.h5
# ../h36m/S8/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S8/MyPoses/3D_positions/Walking.h5
# Reading subject 8, action WalkTogether
# ../h36m/S8/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S8/MyPoses/3D_positions/WalkTogether 1.h5
# ../h36m/S8/MyPoses/3D_positions/WalkTogether 2.h5
# Reading subject 9, action Directions
# ../h36m/S9/MyPoses/3D_positions/Directions*.h5
# ../h36m/S9/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S9/MyPoses/3D_positions/Directions.h5
# Reading subject 9, action Discussion
# ../h36m/S9/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S9/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S9/MyPoses/3D_positions/Discussion 2.h5
# Reading subject 9, action Eating
# ../h36m/S9/MyPoses/3D_positions/Eating*.h5
# ../h36m/S9/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S9/MyPoses/3D_positions/Eating.h5
# Reading subject 9, action Greeting
# ../h36m/S9/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S9/MyPoses/3D_positions/Greeting 1.h5
# ../h36m/S9/MyPoses/3D_positions/Greeting.h5
# Reading subject 9, action Phoning
# ../h36m/S9/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S9/MyPoses/3D_positions/Phoning 1.h5
# ../h36m/S9/MyPoses/3D_positions/Phoning.h5
# Reading subject 9, action Photo
# ../h36m/S9/MyPoses/3D_positions/Photo*.h5
# ../h36m/S9/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S9/MyPoses/3D_positions/Photo.h5
# Reading subject 9, action Posing
# ../h36m/S9/MyPoses/3D_positions/Posing*.h5
# ../h36m/S9/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S9/MyPoses/3D_positions/Posing.h5
# Reading subject 9, action Purchases
# ../h36m/S9/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S9/MyPoses/3D_positions/Purchases.h5
# ../h36m/S9/MyPoses/3D_positions/Purchases 1.h5
# Reading subject 9, action Sitting
# ../h36m/S9/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S9/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S9/MyPoses/3D_positions/Sitting.h5
# Reading subject 9, action SittingDown
# ../h36m/S9/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S9/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S9/MyPoses/3D_positions/SittingDown.h5
# Reading subject 9, action Smoking
# ../h36m/S9/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S9/MyPoses/3D_positions/Smoking 1.h5
# ../h36m/S9/MyPoses/3D_positions/Smoking.h5
# Reading subject 9, action Waiting
# ../h36m/S9/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S9/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S9/MyPoses/3D_positions/Waiting.h5
# Reading subject 9, action WalkDog
# ../h36m/S9/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S9/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S9/MyPoses/3D_positions/WalkDog.h5
# Reading subject 9, action Walking
# ../h36m/S9/MyPoses/3D_positions/Walking*.h5
# ../h36m/S9/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S9/MyPoses/3D_positions/Walking.h5
# Reading subject 9, action WalkTogether
# ../h36m/S9/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S9/MyPoses/3D_positions/WalkTogether 1.h5
# ../h36m/S9/MyPoses/3D_positions/WalkTogether.h5
# Reading subject 11, action Directions
# ../h36m/S11/MyPoses/3D_positions/Directions*.h5
# ../h36m/S11/MyPoses/3D_positions/Directions 1.h5
# ../h36m/S11/MyPoses/3D_positions/Directions.h5
# Reading subject 11, action Discussion
# ../h36m/S11/MyPoses/3D_positions/Discussion*.h5
# ../h36m/S11/MyPoses/3D_positions/Discussion 1.h5
# ../h36m/S11/MyPoses/3D_positions/Discussion 2.h5
# Reading subject 11, action Eating
# ../h36m/S11/MyPoses/3D_positions/Eating*.h5
# ../h36m/S11/MyPoses/3D_positions/Eating 1.h5
# ../h36m/S11/MyPoses/3D_positions/Eating.h5
# Reading subject 11, action Greeting
# ../h36m/S11/MyPoses/3D_positions/Greeting*.h5
# ../h36m/S11/MyPoses/3D_positions/Greeting 2.h5
# ../h36m/S11/MyPoses/3D_positions/Greeting.h5
# Reading subject 11, action Phoning
# ../h36m/S11/MyPoses/3D_positions/Phoning*.h5
# ../h36m/S11/MyPoses/3D_positions/Phoning 2.h5
# ../h36m/S11/MyPoses/3D_positions/Phoning 3.h5
# Reading subject 11, action Photo
# ../h36m/S11/MyPoses/3D_positions/Photo*.h5
# ../h36m/S11/MyPoses/3D_positions/Photo 1.h5
# ../h36m/S11/MyPoses/3D_positions/Photo.h5
# Reading subject 11, action Posing
# ../h36m/S11/MyPoses/3D_positions/Posing*.h5
# ../h36m/S11/MyPoses/3D_positions/Posing 1.h5
# ../h36m/S11/MyPoses/3D_positions/Posing.h5
# Reading subject 11, action Purchases
# ../h36m/S11/MyPoses/3D_positions/Purchases*.h5
# ../h36m/S11/MyPoses/3D_positions/Purchases 1.h5
# ../h36m/S11/MyPoses/3D_positions/Purchases.h5
# Reading subject 11, action Sitting
# ../h36m/S11/MyPoses/3D_positions/Sitting*.h5
# ../h36m/S11/MyPoses/3D_positions/Sitting 1.h5
# ../h36m/S11/MyPoses/3D_positions/Sitting.h5
# Reading subject 11, action SittingDown
# ../h36m/S11/MyPoses/3D_positions/SittingDown*.h5
# ../h36m/S11/MyPoses/3D_positions/SittingDown 1.h5
# ../h36m/S11/MyPoses/3D_positions/SittingDown.h5
# Reading subject 11, action Smoking
# ../h36m/S11/MyPoses/3D_positions/Smoking*.h5
# ../h36m/S11/MyPoses/3D_positions/Smoking 2.h5
# ../h36m/S11/MyPoses/3D_positions/Smoking.h5
# Reading subject 11, action Waiting
# ../h36m/S11/MyPoses/3D_positions/Waiting*.h5
# ../h36m/S11/MyPoses/3D_positions/Waiting 1.h5
# ../h36m/S11/MyPoses/3D_positions/Waiting.h5
# Reading subject 11, action WalkDog
# ../h36m/S11/MyPoses/3D_positions/WalkDog*.h5
# ../h36m/S11/MyPoses/3D_positions/WalkDog 1.h5
# ../h36m/S11/MyPoses/3D_positions/WalkDog.h5
# Reading subject 11, action Walking
# ../h36m/S11/MyPoses/3D_positions/Walking*.h5
# ../h36m/S11/MyPoses/3D_positions/Walking 1.h5
# ../h36m/S11/MyPoses/3D_positions/Walking.h5
# Reading subject 11, action WalkTogether
# ../h36m/S11/MyPoses/3D_positions/WalkTogether*.h5
# ../h36m/S11/MyPoses/3D_positions/WalkTogether.h5
# ../h36m/S11/MyPoses/3D_positions/WalkTogether 1.h5
# /content/gdrive/My Drive/Ramajayam_Gautham_112965275_hw6/src/data_utils.py:419: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   complete_train = copy.deepcopy( np.vstack( train_set.values() ))
# done reading and normalizing data.

# %%
# ============================
#   Define Train/Test Methods
# ============================

#Reference - Paper provided

def train(train_loader, model, criterion, optimizer,
          lr_init=None, lr_now=None, glob_step=None, lr_decay=None, gamma=None,
          max_norm=True):
  
    losses = utils.AverageMeter()

    model.train()

    start = time.time()
    batch_time = 0
    bar = pBar.Bar('>>>', fill='>', max=len(train_loader))

    for i, (inps, tars) in enumerate(train_loader):
        glob_step += 1
        if glob_step % lr_decay == 0 or glob_step == 1:
            lr_now = utils.lr_decay(optimizer, glob_step, lr_init, lr_decay, gamma)
        inputs = Variable(inps.cuda())
        targets = Variable(tars.cuda(async=True))

        outputs = model(inputs)

        optimizer.zero_grad()
        loss = criterion(outputs, targets)
        losses.update(loss.item(), inputs.size(0))
        loss.backward()
        if max_norm:
            nn.utils.clip_grad_norm(model.parameters(), max_norm=1)
        optimizer.step()

        del inputs, targets, outputs
        torch.cuda.empty_cache()
        
        if (i + 1) % 100 == 0:
            batch_time = time.time() - start
            start = time.time()

        bar.suffix = '({batch}/{size}) | batch: {batchtime:.4}ms | Total: {ttl} | ETA: {eta:} | loss: {loss:.4f}' \
            .format(batch=i + 1,
                    size=len(train_loader),
                    batchtime=batch_time * 10.0,
                    ttl=bar.elapsed_td,
                    eta=bar.eta_td,
                    loss=losses.avg)
        bar.next()

    bar.finish()
    return glob_step, lr_now, losses.avg


def test(test_loader, model, criterion, stat_3d, procrustes=False):
    losses = utils.AverageMeter()

    model.eval()

    all_dist = []
    start = time.time()
    batch_time = 0
    bar = pBar.Bar('>>>', fill='>', max=len(test_loader))

    for i, (inps, tars) in enumerate(test_loader):
        inputs = Variable(inps.cuda())
        # inputs = Variable()

        targets = Variable(tars.cuda(async=True))
        # targets = Variable()

        outputs = model(inputs)

        # calculate loss
        outputs_coord = outputs
        loss = criterion(outputs_coord, targets)

        losses.update(loss.item(), inputs.size(0))

        tars = targets

        # calculate erruracy
        targets_unnorm = data_process.unNormalizeData(tars.data.cpu().numpy(), stat_3d['mean'], stat_3d['std'], stat_3d['dim_use'])
        outputs_unnorm = data_process.unNormalizeData(outputs.data.cpu().numpy(), stat_3d['mean'], stat_3d['std'], stat_3d['dim_use'])

        # remove dim ignored
        dim_use = np.hstack((np.arange(3), stat_3d['dim_use']))

        outputs_use = outputs_unnorm[:, dim_use]
        targets_use = targets_unnorm[:, dim_use]

        if procrustes:
            for ba in range(inps.size(0)):
                gt = targets_use[ba].reshape(-1, 3)
                out = outputs_use[ba].reshape(-1, 3)
                _, Z, T, b, c = get_transformation(gt, out, True)
                out = (b * out.dot(T)) + c
                outputs_use[ba, :] = out.reshape(1, 51)

        sqerr = (outputs_use - targets_use) ** 2

        del inputs, targets, outputs
        torch.cuda.empty_cache()

        distance = np.zeros((sqerr.shape[0], 17))
        dist_idx = 0
        for k in np.arange(0, 17 * 3, 3):
            distance[:, dist_idx] = np.sqrt(np.sum(sqerr[:, k:k + 3], axis=1))
            dist_idx += 1
        all_dist.append(distance)

        # update summary
        if (i + 1) % 100 == 0:
            batch_time = time.time() - start
            start = time.time()

        bar.suffix = '({batch}/{size}) | batch: {batchtime:.4}ms | Total: {ttl} | ETA: {eta:} | loss: {loss:.6f}' \
            .format(batch=i + 1,
                    size=len(test_loader),
                    batchtime=batch_time * 10.0,
                    ttl=bar.elapsed_td,
                    eta=bar.eta_td,
                    loss=losses.avg)
        bar.next()

    all_dist = np.vstack(all_dist)
    joint_err = np.mean(all_dist, axis=0)
    ttl_err = np.mean(all_dist)
    bar.finish()
    print (">>> error: {} <<<".format(ttl_err))
    return losses.avg, ttl_err

# %%
# ==================
#   Dataset class
# ==================
from torch.utils.data import Dataset

TRAIN_SUBJECTS = [1, 5, 6, 7, 8]
TEST_SUBJECTS = [9, 11]

class Human36M(Dataset):
    def __init__(self, actions, data_path, use_hg=True, is_train=True):

        self.actions = actions
        self.data_path = data_path

        self.is_train = is_train
        self.use_hg = use_hg

        self.train_inp, self.train_out, self.test_inp, self.test_out = [], [], [], []
        self.train_meta, self.test_meta = [], []

        if self.is_train:
            self.train_3d = train_set_3d
            self.train_2d = train_set_2d
            for k2d in self.train_2d.keys():
                (sub, act, fname) = k2d
                k3d = k2d
                k3d = (sub, act, fname[:-3]) if fname.endswith('-sh') else k3d
                num_f, _ = self.train_2d[k2d].shape
                assert self.train_3d[k3d].shape[0] == self.train_2d[k2d].shape[0], 
                for i in range(num_f):
                    self.train_inp.append(self.train_2d[k2d][i])
                    self.train_out.append(self.train_3d[k3d][i])

        else:
            self.test_3d = test_set_3d
            self.test_2d = test_set_2d
            for k2d in self.test_2d.keys():
                (sub, act, fname) = k2d
                if act not in self.actions:
                    continue
                k3d = k2d
                k3d = (sub, act, fname[:-3]) if fname.endswith('-sh') else k3d
                num_f, _ = self.test_2d[k2d].shape
                assert self.test_2d[k2d].shape[0] == self.test_3d[k3d].shape[0], 
                for i in range(num_f):
                    self.test_inp.append(self.test_2d[k2d][i])
                    self.test_out.append(self.test_3d[k3d][i])

    def __getitem__(self, index):
        if self.is_train:
            inputs = torch.from_numpy(self.train_inp[index]).float()
            outputs = torch.from_numpy(self.train_out[index]).float()

        else:
            inputs = torch.from_numpy(self.test_inp[index]).float()
            outputs = torch.from_numpy(self.test_out[index]).float()

        return inputs, outputs

    def __len__(self):
        if self.is_train:
            return len(self.train_inp)
        else:
            return len(self.test_inp)

# %%
# ==========================================
#       Define Network Architecture
# ==========================================

#Model used in paper obtains better results

def weight_init(m):
    if isinstance(m, nn.Linear):
        nn.init.kaiming_normal(m.weight)

class Linear(nn.Module):
    def __init__(self, linear_size, p_dropout=0.5):
        super(Linear, self).__init__()
        self.l_size = linear_size

        self.relu = nn.ReLU(inplace=True)
        self.dropout = nn.Dropout(p_dropout)

        self.w1 = nn.Linear(self.l_size, self.l_size)
        self.batch_norm1 = nn.BatchNorm1d(self.l_size)

        self.w2 = nn.Linear(self.l_size, self.l_size)
        self.batch_norm2 = nn.BatchNorm1d(self.l_size)

    def forward(self, x):
        y = self.w1(x)
        y = self.batch_norm1(y)
        y = self.relu(y)
        y = self.dropout(y)

        y = self.w2(y)
        y = self.batch_norm2(y)
        y = self.relu(y)
        y = self.dropout(y)

        out = x + y

        return out

class LinearModel(nn.Module):
    def __init__(self,
                 linear_size=1024,
                 num_stage=2,
                 p_dropout=0.5):
        super(LinearModel, self).__init__()

        self.linear_size = linear_size
        self.p_dropout = p_dropout
        self.num_stage = num_stage
        
        self.input_size =  16 * 2        
        self.output_size = 16 * 3
        
        self.w1 = nn.Linear(self.input_size, self.linear_size)
        self.batch_norm1 = nn.BatchNorm1d(self.linear_size)

        self.linear_stages = []
        for l in range(num_stage):
            self.linear_stages.append(Linear(self.linear_size, self.p_dropout))
        self.linear_stages = nn.ModuleList(self.linear_stages)
        
        self.w2 = nn.Linear(self.linear_size, self.output_size)

        self.relu = nn.ReLU(inplace=True)
        self.dropout = nn.Dropout(self.p_dropout)

    def forward(self, x):
        
        y = self.w1(x)
        y = self.batch_norm1(y)
        y = self.relu(y)
        y = self.dropout(y)
        
        for i in range(self.num_stage):
            y = self.linear_stages[i](y)

        y = self.w2(y)

        return y

# %%
# ==========================================
#         load dadasets for training
# ==========================================

job = 8
use_hg = False

test_batch = 64
train_batch = 64

test_loader = DataLoader(
        dataset=Human36M(actions=actions, data_path=data_dir, use_hg=use_hg, is_train=False), batch_size=test_batch, shuffle=False,
        num_workers=job,
        pin_memory=True)
train_loader = DataLoader(
        dataset=Human36M(actions=actions, data_path=data_dir, use_hg=use_hg), batch_size=train_batch, shuffle=True,
        num_workers=job,
        pin_memory=True)

print(">>> data loaded !")
# Out:
# >>> data loaded !

# %%
# ==========================================
#         Optimize/Train Network
# ==========================================

# First 30 epochs
#Values used are from paper

import time

lr = 0.001
lr_now = 0.001
glob_step = 0
lr_decay = 100000
lr_gamma = 0.96
max_norm = True

err_best = 1000

model = LinearModel()
model = model.cuda()
model.apply(weight_init)
print(">>> total params: {:.2f}M".format(sum(p.numel() for p in model.parameters()) / 1000000.0))
criterion = nn.MSELoss(size_average=True).cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=lr_now)

cudnn.benchmark = True
for epoch in range(0, 31):
        print('==========================')
        print('>>> epoch: {} | lr: {:.5f}'.format(epoch + 1, lr_now))
        
        a = time.time() #time per epoch
        glob_step, lr_now, loss_train = train(
            train_loader, model, criterion, optimizer,
            lr_init=lr, lr_now=lr_now, glob_step=glob_step, lr_decay=lr_decay, gamma=lr_gamma,
            max_norm=max_norm)
        loss_test, err_test = test(test_loader, model, criterion, stat_3d, procrustes=True)
        print(loss_test, err_test)
        
        is_best = err_test < err_best
        err_best = min(err_test, err_best)
        if is_best:
            log.save_ckpt({'epoch': epoch + 1,
                           'lr': lr_now,
                           'step': glob_step,
                           'err': err_best,
                           'state_dict': model.state_dict(),
                           'optimizer': optimizer.state_dict()},
                          ckpt_path='checkpoint/',
                          is_best=True)
        else:
            log.save_ckpt({'epoch': epoch + 1,
                           'lr': lr_now,
                           'step': glob_step,
                           'err': err_best,
                           'state_dict': model.state_dict(),
                           'optimizer': optimizer.state_dict()},
                          ckpt_path='checkpoint/',
                          is_best=False)
        print("Time taken:",time.time()-a)
# Out:
# >>> total params: 4.29M
# ==========================
# >>> epoch: 1 | lr: 0.00100
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# >>> error: 44.16342830062885 <<<
# 0.062271871334149444 44.16342830062885
# Time taken: 583.3309705257416
# ==========================
# >>> epoch: 2 | lr: 0.00100
# >>> error: 41.335010902245294 <<<
# 0.052914752104586855 41.335010902245294
# Time taken: 592.1690390110016
# ==========================
# >>> epoch: 3 | lr: 0.00100
# >>> error: 40.66338597753286 <<<
# 0.051187966985762515 40.66338597753286
# Time taken: 582.6607990264893
# ==========================
# >>> epoch: 4 | lr: 0.00100
# >>> error: 39.88021656888935 <<<
# 0.0476029122726344 39.88021656888935
# Time taken: 587.7799677848816
# ==========================
# >>> epoch: 5 | lr: 0.00100
# >>> error: 39.410511587466864 <<<
# 0.04727250566538241 39.410511587466864
# Time taken: 586.3190286159515
# ==========================
# >>> epoch: 6 | lr: 0.00096
# >>> error: 38.72040612475875 <<<
# 0.046448603046232356 38.72040612475875
# Time taken: 589.7871429920197
# ==========================
# >>> epoch: 7 | lr: 0.00096
# >>> error: 39.109270953642955 <<<
# 0.0466180704270544 39.109270953642955
# Time taken: 589.2799422740936
# ==========================
# >>> epoch: 8 | lr: 0.00096
# >>> error: 38.60569749218774 <<<
# 0.045823019195455374 38.60569749218774
# Time taken: 584.9313232898712
# ==========================
# >>> epoch: 9 | lr: 0.00096
# >>> error: 38.587196735226364 <<<
# 0.04614913371107038 38.587196735226364
# Time taken: 584.2278399467468
# ==========================
# >>> epoch: 10 | lr: 0.00092
# >>> error: 37.85936839837131 <<<
# 0.044990485767191786 37.85936839837131
# Time taken: 585.0289766788483
# ==========================
# >>> epoch: 11 | lr: 0.00092
# >>> error: 38.405986948743326 <<<
# 0.046057532941082086 38.405986948743326
# Time taken: 582.241471529007
# ==========================
# >>> epoch: 12 | lr: 0.00092
# >>> error: 37.61978984947753 <<<
# 0.04392650258095753 37.61978984947753
# Time taken: 581.2723619937897
# ==========================
# >>> epoch: 13 | lr: 0.00092
# >>> error: 37.09944352755663 <<<
# 0.042685125191123365 37.09944352755663
# Time taken: 591.554247379303
# ==========================
# >>> epoch: 14 | lr: 0.00088
# >>> error: 36.96568112590599 <<<
# 0.04200298130610091 36.96568112590599
# Time taken: 582.0515449047089
# ==========================
# >>> epoch: 15 | lr: 0.00088
# >>> error: 37.05548955316383 <<<
# 0.043796577624583 37.05548955316383
# Time taken: 583.0868594646454
# ==========================
# >>> epoch: 16 | lr: 0.00088
# >>> error: 37.22578339686292 <<<
# 0.044444970582698175 37.22578339686292
# Time taken: 577.8145637512207
# ==========================
# >>> epoch: 17 | lr: 0.00088
# >>> error: 37.220958374506864 <<<
# 0.04396289460235818 37.220958374506864
# Time taken: 577.2464246749878
# ==========================
# >>> epoch: 18 | lr: 0.00085
# >>> error: 37.11090177721932 <<<
# 0.042793199685852885 37.11090177721932
# Time taken: 583.8498029708862
# ==========================
# >>> epoch: 19 | lr: 0.00085
# >>> error: 36.86389975845119 <<<
# 0.04226041735385888 36.86389975845119
# Time taken: 582.8344013690948
# ==========================
# >>> epoch: 20 | lr: 0.00085
# >>> error: 36.490902416962186 <<<
# 0.042295984044988924 36.490902416962186
# Time taken: 581.1300477981567
# ==========================
# >>> epoch: 21 | lr: 0.00085
# >>> error: 37.008930341197555 <<<
# 0.04366868536901982 37.008930341197555
# Time taken: 583.8923742771149
# ==========================
# >>> epoch: 22 | lr: 0.00082
# >>> error: 37.08431796137638 <<<
# 0.044552842879889386 37.08431796137638
# Time taken: 586.4408419132233
# ==========================
# >>> epoch: 23 | lr: 0.00082
# >>> error: 37.484191177172725 <<<
# 0.04341356998697133 37.484191177172725
# Time taken: 585.5384225845337
# ==========================
# >>> epoch: 24 | lr: 0.00082
# >>> error: 36.5962396034518 <<<
# 0.04205356657068617 36.5962396034518
# Time taken: 573.9568457603455
# ==========================
# >>> epoch: 25 | lr: 0.00082
# >>> error: 37.260501091377265 <<<
# 0.04295939095306952 37.260501091377265
# Time taken: 574.1731052398682
# ==========================
# >>> epoch: 26 | lr: 0.00078
# >>> error: 36.785110349146706 <<<
# 0.044542465381737895 36.785110349146706
# Time taken: 562.3927335739136
# ==========================
# >>> epoch: 27 | lr: 0.00078
# >>> error: 36.775679122848665 <<<
# 0.044242917044644316 36.775679122848665
# Time taken: 579.0127766132355
# ==========================
# >>> epoch: 28 | lr: 0.00078
# >>> error: 36.16595245708211 <<<
# 0.04082344608635727 36.16595245708211
# Time taken: 575.5080728530884
# ==========================
# >>> epoch: 29 | lr: 0.00078
# >>> error: 36.39371439990079 <<<
# 0.041654422230031185 36.39371439990079
# Time taken: 564.1486036777496
# ==========================
# >>> epoch: 30 | lr: 0.00075
# >>> error: 36.66727325685063 <<<
# 0.04206665692762091 36.66727325685063
# Time taken: 573.1256420612335
# ==========================
# >>> epoch: 31 | lr: 0.00075
# >>> error: 36.40931857025031 <<<
# 0.04300415100301162 36.40931857025031
# Time taken: 564.2846517562866

# %%
#Loading saved model for more epochs
#Values used are from paper

import time

#lr = 0.001
lr_now = 0.001
#glob_step = 0
lr_decay = 100000
lr_gamma = 0.96
max_norm = True

model = LinearModel()
model = model.cuda()
model.apply(weight_init)
print(">>> total params: {:.2f}M".format(sum(p.numel() for p in model.parameters()) / 1000000.0))
criterion = nn.MSELoss(size_average=True).cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=lr_now)

print(">>> loading ckpt from '{}'".format('checkpoint/ckpt_best.pth.tar'))
ckpt = torch.load('checkpoint/ckpt_last.pth.tar')
start_epoch = ckpt['epoch']
err_best = ckpt['err']
glob_step = ckpt['step']
lr_now = ckpt['lr']
model.load_state_dict(ckpt['state_dict'])
optimizer.load_state_dict(ckpt['optimizer'])
print(">>> ckpt loaded (epoch: {} | err: {})".format(start_epoch, err_best))

lr = lr_now
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# >>> total params: 4.29M
# >>> loading ckpt from 'checkpoint/ckpt_best.pth.tar'
# >>> ckpt loaded (epoch: 100 | err: 30.704807242162648)

# %%
#Till 100 epochs

cudnn.benchmark = True
for epoch in range(start_epoch, start_epoch+20):
        print('==========================')
        print('>>> epoch: {} | lr: {:.5f}'.format(epoch + 1, lr_now))

        
        a = time.time() #time per epoch
        glob_step, lr_now, loss_train = train(
            train_loader, model, criterion, optimizer,
            lr_init=lr, lr_now=lr_now, glob_step=glob_step, lr_decay=lr_decay, gamma=lr_gamma,
            max_norm=max_norm)
        loss_test, err_test = test(test_loader, model, criterion, stat_3d, procrustes=True)
        print(loss_test, err_test)
        
        is_best = err_test < err_best
        err_best = min(err_test, err_best)
        if is_best:
            print("====Saving Best====")
            log.save_ckpt({'epoch': epoch + 1,
                           'lr': lr_now,
                           'step': glob_step,
                           'err': err_best,
                           'state_dict': model.state_dict(),
                           'optimizer': optimizer.state_dict()},
                          ckpt_path='checkpoint/',
                          is_best=True)
        else:
            print("====Saving====")
            log.save_ckpt({'epoch': epoch + 1,
                           'lr': lr_now,
                           'step': glob_step,
                           'err': err_best,
                           'state_dict': model.state_dict(),
                           'optimizer': optimizer.state_dict()},
                          ckpt_path='checkpoint/',
                          is_best=False)
        print("Time taken:",time.time()-a)
# Out:
# ==========================
# >>> epoch: 81 | lr: 0.00012
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# >>> error: 34.69658919530737 <<<
# 0.03914848711937267 34.69658919530737
# ====Saving====
# Time taken: 551.2632088661194
# ==========================
# >>> epoch: 82 | lr: 0.00012
# >>> error: 34.597894198223074 <<<
# 0.03917786435982963 34.597894198223074
# ====Saving====
# Time taken: 551.1016938686371
# ==========================
# >>> epoch: 83 | lr: 0.00012
# >>> error: 35.0798305701054 <<<
# 0.04042747651386095 35.0798305701054
# ====Saving====
# Time taken: 547.4436078071594
# ==========================
# >>> epoch: 84 | lr: 0.00006
# >>> error: 35.09149184870116 <<<
# 0.03980265689313811 35.09149184870116
# ====Saving====
# Time taken: 553.2564783096313
# ==========================
# >>> epoch: 85 | lr: 0.00006
# >>> error: 35.65330269766996 <<<
# 0.042636073279457364 35.65330269766996
# ====Saving====
# Time taken: 543.4624857902527
# ==========================
# >>> epoch: 86 | lr: 0.00006
# >>> error: 34.70495371903628 <<<
# 0.04020920239246519 34.70495371903628
# ====Saving====
# Time taken: 536.7544333934784
# ==========================
# >>> epoch: 87 | lr: 0.00006
# >>> error: 34.59444237931156 <<<
# 0.03970699470633561 34.59444237931156
# ====Saving====
# Time taken: 545.6696643829346
# ==========================
# >>> epoch: 88 | lr: 0.00005
# >>> error: 34.85250689212479 <<<
# 0.040130474754247754 34.85250689212479
# ====Saving====
# Time taken: 544.840781211853
# ==========================
# >>> epoch: 89 | lr: 0.00005
# >>> error: 35.35694603546621 <<<
# 0.041430497764217505 35.35694603546621
# ====Saving====
# Time taken: 539.6640853881836
# ==========================
# >>> epoch: 90 | lr: 0.00005
# >>> error: 34.8090213819546 <<<
# 0.03959264746042352 34.8090213819546
# ====Saving====
# Time taken: 541.9205911159515
# ==========================
# >>> epoch: 91 | lr: 0.00005
# >>> error: 35.71861770522162 <<<
# 0.0410634741001279 35.71861770522162
# ====Saving====
# Time taken: 542.3853747844696
# ==========================
# >>> epoch: 92 | lr: 0.00005
# >>> error: 35.235787544409106 <<<
# 0.04048131213173186 35.235787544409106
# ====Saving====
# Time taken: 535.6726803779602
# ==========================
# >>> epoch: 93 | lr: 0.00005
# >>> error: 34.79518790549217 <<<
# 0.03986761492740783 34.79518790549217
# ====Saving====
# Time taken: 530.9416561126709
# ==========================
# >>> epoch: 94 | lr: 0.00005
# >>> error: 35.28183226598192 <<<
# 0.042045872438123924 35.28183226598192
# ====Saving====
# Time taken: 533.0410676002502
# ==========================
# >>> epoch: 95 | lr: 0.00005
# >>> error: 35.85952959623597 <<<
# 0.041142859588854545 35.85952959623597
# ====Saving====
# Time taken: 535.1638221740723
# ==========================
# >>> epoch: 96 | lr: 0.00005
# >>> error: 34.469185521236184 <<<
# 0.038660591951002715 34.469185521236184
# ====Saving====
# Time taken: 530.564131975174
# ==========================
# >>> epoch: 97 | lr: 0.00005
# >>> error: 34.716865682856266 <<<
# 0.039676262465234126 34.716865682856266
# ====Saving====
# Time taken: 538.589626789093
# ==========================
# >>> epoch: 98 | lr: 0.00005
# >>> error: 35.08032316391911 <<<
# 0.04096086195422843 35.08032316391911
# ====Saving====
# Time taken: 551.5161390304565
# ==========================
# >>> epoch: 99 | lr: 0.00005
# >>> error: 34.39422648438495 <<<
# 0.03901370530412837 34.39422648438495
# ====Saving====
# Time taken: 536.3327629566193
# ==========================
# >>> epoch: 100 | lr: 0.00005
# >>> error: 35.017474963832846 <<<
# 0.040898492459311875 35.017474963832846
# ====Saving====
# Time taken: 530.3831930160522

# %%
# ==========================================
#            Evaluating Network
# ==========================================

err_set = []
for action in actions:
    print (">>> TEST on _{}_".format(action))
    test_loader = DataLoader(dataset=Human36M(actions=action, data_path=data_dir, use_hg=use_hg, is_train=False), batch_size=test_batch,
                shuffle=False,
                num_workers=job,
                pin_memory=True)
    _, err_test = test(test_loader, model, criterion, stat_3d, procrustes=True)
    err_set.append(err_test)

print (">>>>>> TEST results:")
for action in actions:
    print ("{}".format(action), end='\t')
print ("\n")
for err in err_set:
    print ("{:.4f}".format(err), end='\t')
print (">>>\nERRORS: {}".format(np.array(err_set).mean()))
# Out:
# >>> TEST on _Directions_
# >>> error: 28.903461769538954 <<<
# >>> TEST on _Discussion_
# >>> error: 33.61223548197831 <<<
# >>> TEST on _Eating_
# >>> error: 32.81205342385001 <<<
# >>> TEST on _Greeting_
# >>> error: 33.86463032010175 <<<
# >>> TEST on _Phoning_
# >>> error: 34.80027968228955 <<<
# >>> TEST on _Photo_
# >>> error: 40.785184009564425 <<<
# >>> TEST on _Posing_
# >>> error: 34.01720307063561 <<<
# >>> TEST on _Purchases_
# >>> error: 30.551604272946385 <<<
# >>> TEST on _Sitting_
# >>> error: 40.94486828517665 <<<
# >>> TEST on _SittingDown_
# >>> error: 42.81367475139298 <<<
# >>> TEST on _Smoking_
# >>> error: 35.635441440174 <<<
# >>> TEST on _Waiting_
# >>> error: 34.61312725397749 <<<
# >>> TEST on _WalkDog_
# >>> error: 36.851558407054924 <<<
# >>> TEST on _Walking_
# >>> error: 28.05024191599395 <<<
# >>> TEST on _WalkTogether_
# >>> error: 32.5005838581101 <<<
# >>>>>> TEST results:
# Directions	Discussion	Eating	Greeting	Phoning	Photo	Posing	Purchases	Sitting	SittingDown	Smoking	Waiting	WalkDog	Walking	WalkTogether
#
# 28.9035	33.6122	32.8121	33.8646	34.8003	40.7852	34.0172	30.5516	40.9449	42.8137	35.6354	34.6131	36.8516	28.0502	32.5006	>>>
# ERRORS: 34.717076529519005

# %%
print (">>>>>> TEST results:")
print("direct. discuss. eat. greet. phone photo pose purch. sit sitd. somke wait walkd. walk walkT avg")
for err in err_set:
    print ("{:.4f}".format(err), end='\t')
print (">>>\nERRORS: {}".format(np.array(err_set).mean()))
# Out:
# >>>>>> TEST results:
# direct. discuss. eat. greet. phone photo pose purch. sit sitd. somke wait walkd. walk walkT avg
# 28.9035	33.6122	32.8121	33.8646	34.8003	40.7852	34.0172	30.5516	40.9449	42.8137	35.6354	34.6131	36.8516	28.0502	32.5006	>>>
# ERRORS: 34.717076529519005

# %%
# ==========================================
#            Evaluating Network
# ==========================================

err_set = []
for action in actions:
    print (">>> TEST on _{}_".format(action))
    test_loader = DataLoader(
                dataset=Human36M(actions=action, data_path=data_dir, use_hg=use_hg, is_train=False),
                batch_size=test_batch,
                shuffle=False,
                num_workers=job,
                pin_memory=True)
    _, err_test = test(test_loader, model, criterion, stat_3d, procrustes=True)
    err_set.append(err_test)

print (">>>>>> TEST results:")
for action in actions:
    print ("{}".format(action), end='\t')
print ("\n")
for err in err_set:
    print ("{:.4f}".format(err), end='\t')
print (">>>\nERRORS: {}".format(np.array(err_set).mean()))
# Out:
# >>> TEST on _Directions_
# >>> error: 28.984126929110978 <<<
# >>> TEST on _Discussion_
# >>> error: 33.405453925680874 <<<
# >>> TEST on _Eating_
# >>> error: 32.67819362585235 <<<
# >>> TEST on _Greeting_
# >>> error: 34.33603890926346 <<<
# >>> TEST on _Phoning_
# >>> error: 34.688561645686875 <<<
# >>> TEST on _Photo_
# >>> error: 41.11918494288262 <<<
# >>> TEST on _Posing_
# >>> error: 33.94295910125997 <<<
# >>> TEST on _Purchases_
# >>> error: 30.31905645383391 <<<
# >>> TEST on _Sitting_
# >>> error: 41.189174879977145 <<<
# >>> TEST on _SittingDown_
# >>> error: 43.06959473522413 <<<
# >>> TEST on _Smoking_
# >>> error: 35.642790110366015 <<<
# >>> TEST on _Waiting_
# >>> error: 34.53417429302261 <<<
# >>> TEST on _WalkDog_
# >>> error: 36.91773156582341 <<<
# >>> TEST on _Walking_
# >>> error: 28.23993833247055 <<<
# >>> TEST on _WalkTogether_
# >>> error: 32.49097695266145 <<<
# >>>>>> TEST results:
# Directions	Discussion	Eating	Greeting	Phoning	Photo	Posing	Purchases	Sitting	SittingDown	Smoking	Waiting	WalkDog	Walking	WalkTogether
#
# 28.9841	33.4055	32.6782	34.3360	34.6886	41.1192	33.9430	30.3191	41.1892	43.0696	35.6428	34.5342	36.9177	28.2399	32.4910	>>>
# ERRORS: 34.77053042687443

# %%
print (">>>>>> TEST results:")
print("direct. discuss. eat. greet. phone photo pose purch. sit sitd. somke wait walkd. walk walkT avg")
for err in err_set:
    print ("{:.4f}".format(err), end='\t')
print (">>>\nERRORS: {}".format(np.array(err_set).mean()))
# Out:
# >>>>>> TEST results:
# direct. discuss. eat. greet. phone photo pose purch. sit sitd. somke wait walkd. walk walkT avg
# 28.9841	33.4055	32.6782	34.3360	34.6886	41.1192	33.9430	30.3191	41.1892	43.0696	35.6428	34.5342	36.9177	28.2399	32.4910	>>>
# ERRORS: 34.77053042687443

# %% [markdown]
# Report the test result(mm error) in the following sequence **direct.	discuss.	eat.	greet.	phone	photo	pose	purch.	sit	sitd.	somke	wait	walkd.	walk	walkT	avg**

# %% [markdown]
# ## Problem 2:
# {40 points} In this task, we’re going to tackle the situation of having a faulty 3D sensor. Since the sensor is quite old it’s joint detections are quite noisy:
# \begin{equation*}
#  \hat{x} = x_{GT} + \epsilon_x \\
#  \hat{y} = y_{GT} + \epsilon_y \\
#  \hat{z} = z_{GT} + \epsilon_z
# \end{equation*}
#
# Where, ($x_{GT}, y_{GT}, z_{GT}$) are the ground truth joint locations, ($\hat{x}, \hat{y}, \hat{z}$) are the noisy measurements detected by our sensor and ($\epsilon_x, \epsilon_y, \epsilon_z$) are the noise values. Being grad students, we’d much rather the department spend money for free coffee and doughnuts than on a new 3D sensor. Therefore, you’re going to denoise the noisy data using a linear Kalman filter.
#
# **Modelling the state using velocity and acceleration**: We assume a simple, if unrealistic model, of our system - we’re only going to use the position, velocity and acceleration of the joints to denoise the data. The underlying equations representing our assumptions are:
# \begin{equation}
#  x_{t+1} = x_{t} + \frac{\partial x_t}{\partial t} \delta t + 0.5*\frac{\partial^2 x_t}{\partial t^2} \delta t^2 \quad\quad (1)\\
#  y_{t+1} = y_{t} + \frac{\partial y_t}{\partial t} \delta t + 0.5*\frac{\partial^2 y_t}{\partial t^2} \delta t^2 \quad\quad (2)\\
#   z_{t+1} = z_{t} + \frac{\partial z_t}{\partial t} \delta t + 0.5*\frac{\partial^2 z_t}{\partial t^2} \delta t^2 \quad\quad (3) \\
# \end{equation}
# The only measurements/observations we have (i.e our 'observation space') are the noisy joint locations as recorded by the 3D sensors $o_{t} = (\hat{x}_{t}, \hat{y}_{t}, \hat{z}_{t}$). The corresponding state-space would be $z_{t} = (x_{t}, y_{t}, z_{t}, \frac{\partial x_{t}}{\partial t}, \frac{\partial y_{t}}{\partial t}, \frac{\partial z_{t}}{\partial t}, \frac{\partial^2 x_{t}}{\partial t^2}, \frac{\partial^2 y_{t}}{\partial t^2}, \frac{\partial^2 z_{t}}{\partial t^2})$.
#
# Formallly, a linear Kalman filter assumes the underlying dynamics of the system to be a linear Gaussian model i.e.
# \begin{equation*}
#  z_{0} \sim N(\mu_0, \Sigma_0) \\
#  z_{t+1} = A z_{t} + b + \epsilon^1_t \\
#  o_{t} = C z_{t} + d + \epsilon^2_t \\
#  \epsilon^1_t \sim N(0, Q) \\
#  \epsilon^2_t \sim N(0, R)
# \end{equation*}
# where, $A$ and $C$ are the `transition_matrix` and `observation_matrix` respectively, that you are going to define based on equations (1), (2) and (3). The intitial estimates of other parameters can be assumed as:
#
# \begin{equation*}
#  \texttt{initial_state_mean} := \mu_{0} = mean(given \space data) \\
#  \texttt{initial_state_covariance} := \Sigma_{0} = Cov(given \space data) \\
#  \texttt{transition_offset} := b = 0 \\
# \texttt{observation_offset} := d = 0 \\
#  \texttt{transition_covariance} := Q = I \\
#  \texttt{observation_covariance} :=R = I \\
# \end{equation*}
#
# The covariance matrices $Q$ and $R$ are hyperparameters that we initalize as identity matrices. In the code below, you must define $A$ and $C$ and use [pykalman](https://pykalman.github.io/), a dedicated library for kalman filtering in python, to filter out the noise in the data.
#
# (**Hint:** \\
# Gradients could be calculated using `np.gradient` or manually using finite differences \\
# You can assume the frame rate to be 50Hz)
#
# For more detailed resources related to Kalman filtering, please refer to: \\
# http://web.mit.edu/kirtley/kirtley/binlustuff/literature/control/Kalman%20filter.pdf \\
# https://www.bzarg.com/p/how-a-kalman-filter-works-in-pictures/ \\
# https://stanford.edu/class/ee363/lectures/kf.pdf

# %%
'''=================Function definition of the Kalman filter, which will return the filtered 3D world coordinates============================'''
'''=================Students need to fill this part================================'''
from pykalman import KalmanFilter

def KF_filter(noisy_obs):
  
  noisy_obs = noisy_obs  
  cov_noisy = np.cov(noisy_obs.T)
  mean_noisy = np.mean(noisy_obs, axis = 0)
  
  init_state_X = np.random.multivariate_normal(mean = mean_noisy, cov = cov_noisy, size = 1)  
  X = np.concatenate((init_state_X, noisy_obs))
  
  V = np.diff(X, axis = 0)  #Finite differences using np.diff
  mean_V = np.mean(V, axis = 0)
  cov_V = np.cov(V.T)
  init_state_V = np.random.multivariate_normal(mean = mean_V, cov = cov_V, size = 1)  
  V = np.concatenate((init_state_V, V))
  
  A = np.diff(V, axis = 0)  
  mean_A = np.mean(A, axis = 0)
  cov_A = np.cov(A.T)
  init_state_A = np.random.multivariate_normal(mean = mean_A, cov = cov_A, size = 1)
  A = np.concatenate((init_state_A, A))

  trans_mat = np.zeros((9,9))
  trans_mat[0][0] = trans_mat[1][1] = trans_mat[2][2] = 1 #x eq1 
  trans_mat[0][3] = trans_mat[1][4] = trans_mat[2][5] = 1 #v eq1    #Mathematically for every time step, delta_t (time for each frame rate) 
  trans_mat[0][6] = trans_mat[1][7] = trans_mat[2][8] = 0.5 #a eq1  #gets cancelled in these equations of motion and velocity and acceleration  
  trans_mat[3][3] = trans_mat[4][4] = trans_mat[5][5] = 1 #v eq2    #become finite differences. If delta_t and time step value were different then 
  trans_mat[3][6] = trans_mat[4][7] = trans_mat[5][8] = 1 #a eq2    #we need to include delta_t in these equations 
  trans_mat[6][6] = trans_mat[7][7] = trans_mat[8][8] = 1 #a eq3
  
  obs_mat = np.zeros((9,9))
  obs_mat[0][0] = obs_mat[1][1] = obs_mat[2][2] = 1
  
  kf = KalmanFilter(em_vars=['transition_covariance', 'observation_covariance'], transition_matrices = trans_mat, observation_matrices = obs_mat)

  a = b = 0  
  i = j = 0
  
  for i in range(16):

    Z = np.empty((noisy_obs.shape[0]+1,9))
    
    for j in range(noisy_obs.shape[0]+1):
      Z[j] = np.concatenate((X[j][3*i:3*(i+1)], V[j][3*i:3*(i+1)], A[j][3*i:3*(i+1)]), axis = 0)
       
    print("+===========================================+")
    measurements = Z
    
    a,b = kf.filter(measurements) #Gives out filtered means and filtered covariances
    
    if i == 0:
        filtered_data = a[1:].T[0:3]
    else:
       filtered_data = np.concatenate((filtered_data,a[1:].T[0:3]), axis = 0)
       print("Joint", i, filtered_data.shape)       
    
  return filtered_data.T

# %%
print(list(train_set_3d.keys())[:40])
# Out:
# [(1, 'Directions', 'Directions 1.54138969.h5'), (1, 'Directions', 'Directions 1.55011271.h5'), (1, 'Directions', 'Directions 1.58860488.h5'), (1, 'Directions', 'Directions 1.60457274.h5'), (1, 'Directions', 'Directions.54138969.h5'), (1, 'Directions', 'Directions.55011271.h5'), (1, 'Directions', 'Directions.58860488.h5'), (1, 'Directions', 'Directions.60457274.h5'), (1, 'Discussion', 'Discussion 1.54138969.h5'), (1, 'Discussion', 'Discussion 1.55011271.h5'), (1, 'Discussion', 'Discussion 1.58860488.h5'), (1, 'Discussion', 'Discussion 1.60457274.h5'), (1, 'Discussion', 'Discussion.54138969.h5'), (1, 'Discussion', 'Discussion.55011271.h5'), (1, 'Discussion', 'Discussion.58860488.h5'), (1, 'Discussion', 'Discussion.60457274.h5'), (1, 'Eating', 'Eating 2.54138969.h5'), (1, 'Eating', 'Eating 2.55011271.h5'), (1, 'Eating', 'Eating 2.58860488.h5'), (1, 'Eating', 'Eating 2.60457274.h5'), (1, 'Eating', 'Eating.54138969.h5'), (1, 'Eating', 'Eating.55011271.h5'), (1, 'Eating', 'Eating.58860488.h5'), (1, 'Eating', 'Eating.60457274.h5'), (1, 'Greeting', 'Greeting 1.54138969.h5'), (1, 'Greeting', 'Greeting 1.55011271.h5'), (1, 'Greeting', 'Greeting 1.58860488.h5'), (1, 'Greeting', 'Greeting 1.60457274.h5'), (1, 'Greeting', 'Greeting.54138969.h5'), (1, 'Greeting', 'Greeting.55011271.h5'), (1, 'Greeting', 'Greeting.58860488.h5'), (1, 'Greeting', 'Greeting.60457274.h5'), (1, 'Phoning', 'Phoning 1.54138969.h5'), (1, 'Phoning', 'Phoning 1.55011271.h5'), (1, 'Phoning', 'Phoning 1.58860488.h5'), (1, 'Phoning', 'Phoning 1.60457274.h5'), (1, 'Phoning', 'Phoning.54138969.h5'), (1, 'Phoning', 'Phoning.55011271.h5'), (1, 'Phoning', 'Phoning.58860488.h5'), (1, 'Phoning', 'Phoning.60457274.h5')]

# %%
"""
true_data = np.asarray(train_set_3d[(1, 'Directions', 'Directions 1.60457274.h5')])
noise = np.random.multivariate_normal(mean = np.zeros(true_data.shape[1]), cov = cov, size = true_data.shape[0])
noisy_obs = true_data + noise
l = train_set_3d[(1, 'Directions', 'Directions 1.60457274.h5')]
r, c = noisy_obs.shape
cov_noisy = np.cov(noisy_obs.T)
mean_noisy = np.mean(noisy_obs, axis = 0)
#print(mean_noisy.shape)
init_state_X = np.random.multivariate_normal(mean = mean_noisy, cov = cov_noisy, size = 1)
#print(noisy_obs.shape, init_state.shape)
X = np.concatenate((init_state_X, noisy_obs))
#print(X.shape)
V = np.diff(X, axis = 0)
#print(V.shape)
mean_V = np.mean(V, axis = 0)
cov_V = np.cov(V.T)
init_state_V = np.random.multivariate_normal(mean = mean_V, cov = cov_V, size = 1)
#print(init_state_V.shape)
V = np.concatenate((init_state_V, V))
#print(V.shape)
A = np.diff(V, axis = 0)
#print(A.shape)
mean_A = np.mean(A, axis = 0)
cov_A = np.cov(A.T)
init_state_A = np.random.multivariate_normal(mean = mean_A, cov = cov_A, size = 1)
A = np.concatenate((init_state_A, A))
#print(A.shape)

co_ords = np.empty((r,16,3))
#print(co_ords.shape)
for i in range(r):
  co_ords[i] = np.reshape(noisy_obs[i], (16,3))
  #print(co_ords[i].shape)

cov = np.cov(noisy_obs.T)
#print(cov.shape)  
"""

# %%
"""
trans_mat = np.zeros((9,9))
trans_mat[0][0] = trans_mat[1][1] = trans_mat[2][2] = 1 #x 1 
trans_mat[0][3] = trans_mat[1][4] = trans_mat[2][5] = 1 #v 1
trans_mat[0][6] = trans_mat[1][7] = trans_mat[2][8] = 0.5 #a 1
trans_mat[3][3] = trans_mat[4][4] = trans_mat[5][5] = 1 #v 2
trans_mat[3][6] = trans_mat[4][7] = trans_mat[5][8] = 1 #a 2
trans_mat[6][6] = trans_mat[7][7] = trans_mat[8][8] = 1 #a 3
print(trans_mat)

obs_mat = np.zeros((9,9))
obs_mat[0][0] = obs_mat[1][1] = obs_mat[2][2] = 1
print(obs_mat)

print(X.shape, V.shape, A.shape)
"""

# %%
"""
print(X[1][0:3], V[1][0:3], A[1][0:3])
print(np.concatenate((X[0][0:3], V[0][0:3], A[0][0:3]), axis = 0))
"""

# %%
"""
Example code from PyKalman page

from pykalman import KalmanFilter
import numpy as np
kf = KalmanFilter(transition_matrices = [[1, 1], [0, 1]], observation_matrices = [[0.1, 0.5], [-0.3, 0.0]])
measurements = np.asarray([[1,0], [0,0], [0,1]])  # 3 observations
kf = kf.em(measurements, n_iter=5)
(filtered_state_means, filtered_state_covariances) = kf.filter(measurements)
(smoothed_state_means, smoothed_state_covariances) = kf.smooth(measurements)
print(filtered_state_means)
print("h",filtered_state_covariances)
"""

# %%
#em_vars=['transition_covariance', 'observation_covariance']
"""
kf = KalmanFilter(em_vars=['transition_covariance', 'observation_covariance'], transition_matrices = trans_mat, observation_matrices = obs_mat)
"""

# %%
"""
from pykalman import KalmanFilter
a = b = 0
#Z = []
i = j = 0
Z = np.empty((1384,9))
for i in range(16):
  Z = np.empty((1384,9))
  #Z = []
  for j in range(1384):
    Z[j] = np.concatenate((X[j][3*i:3*(i+1)], V[j][3*i:3*(i+1)], A[j][3*i:3*(i+1)]), axis = 0)
    #Z.append(np.concatenate((X[j][3*i:3*(i+1)], V[j][3*i:3*(i+1)], A[j][3*i:3*(i+1)]), axis = 0))
    #print(Z[j]) 
  print("+===========================================+")
  measurements = Z
  #print(Z[1383], measurements)
  #kf = kf.em(measurements, n_iter=2)
  print(i, j, measurements.shape)
  print(measurements[0])
  a,b = kf.filter(measurements)
  #print(len(a), len(a[0]), len(b), len(b[0]))
  #print("Error", mean_squared_error(true_data.T[3*i:3*(i+1)],Z[1:].T[0:3]))
  #print("Data Error", mean_squared_error(a[1:].T[0:3], true_data.T[3*i:3*(i+1)]))
  print(mean_squared_error(true_data.T[3*i:3*(i+1)],Z[1:].T[0:3]) - mean_squared_error(a[1:].T[0:3], true_data.T[3*i:3*(i+1)]))
"""
# Out:
# +===========================================+
# 0 1383 (1384, 9)
# [-1.73723521 -1.78253603 -0.36656771  0.33474787 -2.1789055   1.60467703
#  -0.0380537   1.06628428 -2.66473423]
# 0.3338347305992313
# +===========================================+
# 1 1383 (1384, 9)
# [-1.10388676  0.35242056  0.17356805  0.81839411  0.14205239 -0.53609374
#  -1.17203323 -0.59349722  1.68958275]
# 0.04561337050733277
# +===========================================+
# 2 1383 (1384, 9)
# [-0.52437605  0.68993406  0.22353827  1.0055347   0.47416526 -1.33959253
#  -0.00417427 -0.47692481  2.1408515 ]
# 0.04039404740753655
# +===========================================+
# 3 1383 (1384, 9)
# [ 1.73724811  1.78255233  0.36657101 -0.33474996  2.17892585 -1.60468794
#   0.03805394 -1.06629723  2.66475507]
# 0.333839623613724
# +===========================================+
# 4 1383 (1384, 9)
# [-0.10647128  0.50552252  0.81879393 -0.58216396 -0.04930379  0.02941118
#   1.53108189 -0.25792382  1.15474493]
# 0.027169882821169583
# +===========================================+
# 5 1383 (1384, 9)
# [-0.88189495  0.26620558  1.4438781  -0.93591923 -0.16466547  0.12362255
#   0.91918545 -0.28913161  1.06684089]
# 0.03754619521759428
# +===========================================+
# 6 1383 (1384, 9)
# [ 0.12529759 -0.58768953  0.70805999  1.01600907  0.51945216 -1.05951299
#  -0.61230569 -0.43272483 -0.09842162]
# 0.17174942728039588
# +===========================================+
# 7 1383 (1384, 9)
# [-0.22119772 -0.61949702  0.23012117  0.47204385  0.84039361 -2.33047152
#  -0.60581738 -0.87474332  2.02403801]
# 0.1791477563282926
# +===========================================+
# 8 1383 (1384, 9)
# [-0.30591796 -0.19893321 -0.72485711  0.71622546  0.26109433 -0.6914851
#   0.83965572  0.32422563  0.53822964]
# 0.12690922489634526
# +===========================================+
# 9 1383 (1384, 9)
# [ 0.01347987 -0.34136038 -0.12815243  0.85177958  0.71709583 -2.43562191
#   0.47231107 -0.38334273  0.89168771]
# 0.1789331610246334
# +===========================================+
# 10 1383 (1384, 9)
# [ 2.05462239 -0.91329521 -0.53629495  0.24226551 -0.16518388 -3.4658312
#  -0.48071568 -1.02905454  4.41591803]
# 0.2480115901865807
# +===========================================+
# 11 1383 (1384, 9)
# [ 2.9672866  -1.65437092 -4.51889245  1.19345658 -6.48391574 -1.51703179
#  -0.33337865  6.35290081  3.16955336]
# 0.9930674746701857
# +===========================================+
# 12 1383 (1384, 9)
# [ 1.04888566 -1.21968104 -6.85412289 -0.28649207 -5.13114912  2.68723521
#   3.54476308  2.9469697  -0.16297918]
# 1.4847245872858927
# +===========================================+
# 13 1383 (1384, 9)
# [-1.69104837 -0.80148014  0.02762968  0.47601733  1.7037251   0.01909008
#  -0.20712567 -2.03692531 -2.18299953]
# 0.28751970466065724
# +===========================================+
# 14 1383 (1384, 9)
# [-1.51528008 -0.68692614 -0.63713663 -0.9444523   6.26653396  6.68382877
#   5.49729872 -8.61608826 -9.62231038]
# 1.08133000513328
# +===========================================+
# 15 1383 (1384, 9)
# [-2.57766631 -0.81888287 -2.07700524 -2.74760091  2.23512501  8.93167816
#   7.55578532 -7.18387054 -7.779656  ]
# 1.380918972124224

# %%
noisy_stat = []
recovered_stat = []
i = 1
for keys in list(train_set_3d.keys())[:40]:

    print("Key:", i)
    i += 1

    true_state = train_set_3d[keys]
    cov = np.cov(true_state.T)

    noise = np.random.multivariate_normal(mean = np.zeros(true_state.shape[1]), cov = cov, size = true_state.shape[0])
    noisy_observation = true_state + noise
    
    filtered_onservation = KF_filter(noisy_observation)
    noisy_stat.append(mean_squared_error(true_state, noisy_observation))
    recovered_stat.append(mean_squared_error(true_state, filtered_onservation))
# Out:
# Key: 1
# +===========================================+
# +===========================================+
# Joint 1 (6, 1383)
# +===========================================+
# Joint 2 (9, 1383)
# +===========================================+
# Joint 3 (12, 1383)
# +===========================================+
# Joint 4 (15, 1383)
# +===========================================+
# Joint 5 (18, 1383)
# +===========================================+
# Joint 6 (21, 1383)
# +===========================================+
# Joint 7 (24, 1383)
# +===========================================+
# Joint 8 (27, 1383)
# +===========================================+
# Joint 9 (30, 1383)
# +===========================================+
# Joint 10 (33, 1383)
# +===========================================+
# Joint 11 (36, 1383)
# +===========================================+
# Joint 12 (39, 1383)
# +===========================================+
# Joint 13 (42, 1383)
# +===========================================+
# Joint 14 (45, 1383)
# +===========================================+
# Joint 15 (48, 1383)
# Key: 2
# +===========================================+
# +===========================================+
# Joint 1 (6, 1383)
# +===========================================+
# Joint 2 (9, 1383)
# +===========================================+
# Joint 3 (12, 1383)
# +===========================================+
# Joint 4 (15, 1383)
# +===========================================+
# Joint 5 (18, 1383)
# +===========================================+
# Joint 6 (21, 1383)
# +===========================================+
# Joint 7 (24, 1383)
# +===========================================+
# Joint 8 (27, 1383)
# +===========================================+
# Joint 9 (30, 1383)
# +===========================================+
# Joint 10 (33, 1383)
# +===========================================+
# Joint 11 (36, 1383)
# +===========================================+
# Joint 12 (39, 1383)
# +===========================================+
# Joint 13 (42, 1383)
# +===========================================+
# Joint 14 (45, 1383)
# +===========================================+
# Joint 15 (48, 1383)
# Key: 3
# +===========================================+
# +===========================================+
# Joint 1 (6, 1383)
# +===========================================+
# Joint 2 (9, 1383)
# +===========================================+
# Joint 3 (12, 1383)
# +===========================================+
# Joint 4 (15, 1383)
# +===========================================+
# Joint 5 (18, 1383)
# +===========================================+
# Joint 6 (21, 1383)
# +===========================================+
# Joint 7 (24, 1383)
# +===========================================+
# Joint 8 (27, 1383)
# +===========================================+
# Joint 9 (30, 1383)
# +===========================================+
# Joint 10 (33, 1383)
# +===========================================+
# Joint 11 (36, 1383)
# +===========================================+
# Joint 12 (39, 1383)
# +===========================================+
# Joint 13 (42, 1383)
# +===========================================+
# Joint 14 (45, 1383)
# +===========================================+
# Joint 15 (48, 1383)
# Key: 4
# +===========================================+
# +===========================================+
# Joint 1 (6, 1383)
# +===========================================+
# Joint 2 (9, 1383)
# +===========================================+
# Joint 3 (12, 1383)
# +===========================================+
# Joint 4 (15, 1383)
# +===========================================+
# Joint 5 (18, 1383)
# +===========================================+
# Joint 6 (21, 1383)
# +===========================================+
# Joint 7 (24, 1383)
# +===========================================+
# Joint 8 (27, 1383)
# +===========================================+
# Joint 9 (30, 1383)
# +===========================================+
# Joint 10 (33, 1383)
# +===========================================+
# Joint 11 (36, 1383)
# +===========================================+
# Joint 12 (39, 1383)
# +===========================================+
# Joint 13 (42, 1383)
# +===========================================+
# Joint 14 (45, 1383)
# +===========================================+
# Joint 15 (48, 1383)
# Key: 5
# +===========================================+
# +===========================================+
# Joint 1 (6, 1612)
# +===========================================+
# Joint 2 (9, 1612)
# +===========================================+
# Joint 3 (12, 1612)
# +===========================================+
# Joint 4 (15, 1612)
# +===========================================+
# Joint 5 (18, 1612)
# +===========================================+
# Joint 6 (21, 1612)
# +===========================================+
# Joint 7 (24, 1612)
# +===========================================+
# Joint 8 (27, 1612)
# +===========================================+
# Joint 9 (30, 1612)
# +===========================================+
# Joint 10 (33, 1612)
# +===========================================+
# Joint 11 (36, 1612)
# +===========================================+
# Joint 12 (39, 1612)
# +===========================================+
# Joint 13 (42, 1612)
# +===========================================+
# Joint 14 (45, 1612)
# +===========================================+
# Joint 15 (48, 1612)
# Key: 6
# +===========================================+
# +===========================================+
# Joint 1 (6, 1612)
# +===========================================+
# Joint 2 (9, 1612)
# +===========================================+
# Joint 3 (12, 1612)
# +===========================================+
# Joint 4 (15, 1612)
# +===========================================+
# Joint 5 (18, 1612)
# +===========================================+
# Joint 6 (21, 1612)
# +===========================================+
# Joint 7 (24, 1612)
# +===========================================+
# Joint 8 (27, 1612)
# +===========================================+
# Joint 9 (30, 1612)
# +===========================================+
# Joint 10 (33, 1612)
# +===========================================+
# Joint 11 (36, 1612)
# +===========================================+
# Joint 12 (39, 1612)
# +===========================================+
# Joint 13 (42, 1612)
# +===========================================+
# Joint 14 (45, 1612)
# +===========================================+
# Joint 15 (48, 1612)
# Key: 7
# +===========================================+
# +===========================================+
# Joint 1 (6, 1612)
# +===========================================+
# Joint 2 (9, 1612)
# +===========================================+
# Joint 3 (12, 1612)
# +===========================================+
# Joint 4 (15, 1612)
# +===========================================+
# Joint 5 (18, 1612)
# +===========================================+
# Joint 6 (21, 1612)
# +===========================================+
# Joint 7 (24, 1612)
# +===========================================+
# Joint 8 (27, 1612)
# +===========================================+
# Joint 9 (30, 1612)
# +===========================================+
# Joint 10 (33, 1612)
# +===========================================+
# Joint 11 (36, 1612)
# +===========================================+
# Joint 12 (39, 1612)
# +===========================================+
# Joint 13 (42, 1612)
# +===========================================+
# Joint 14 (45, 1612)
# +===========================================+
# Joint 15 (48, 1612)
# Key: 8
# +===========================================+
# +===========================================+
# Joint 1 (6, 1612)
# +===========================================+
# Joint 2 (9, 1612)
# +===========================================+
# Joint 3 (12, 1612)
# +===========================================+
# Joint 4 (15, 1612)
# +===========================================+
# Joint 5 (18, 1612)
# +===========================================+
# Joint 6 (21, 1612)
# +===========================================+
# Joint 7 (24, 1612)
# +===========================================+
# Joint 8 (27, 1612)
# +===========================================+
# Joint 9 (30, 1612)
# +===========================================+
# Joint 10 (33, 1612)
# +===========================================+
# Joint 11 (36, 1612)
# +===========================================+
# Joint 12 (39, 1612)
# +===========================================+
# Joint 13 (42, 1612)
# +===========================================+
# Joint 14 (45, 1612)
# +===========================================+
# Joint 15 (48, 1612)
# Key: 9
# +===========================================+
# +===========================================+
# Joint 1 (6, 3805)
# +===========================================+
# Joint 2 (9, 3805)
# +===========================================+
# Joint 3 (12, 3805)
# +===========================================+
# Joint 4 (15, 3805)
# +===========================================+
# Joint 5 (18, 3805)
# +===========================================+
# Joint 6 (21, 3805)
# +===========================================+
# Joint 7 (24, 3805)
# +===========================================+
# Joint 8 (27, 3805)
# +===========================================+
# Joint 9 (30, 3805)
# +===========================================+
# Joint 10 (33, 3805)
# +===========================================+
# Joint 11 (36, 3805)
# +===========================================+
# Joint 12 (39, 3805)
# +===========================================+
# Joint 13 (42, 3805)
# +===========================================+
# Joint 14 (45, 3805)
# +===========================================+
# Joint 15 (48, 3805)
# Key: 10
# +===========================================+
# +===========================================+
# Joint 1 (6, 3805)
# +===========================================+
# Joint 2 (9, 3805)
# +===========================================+
# Joint 3 (12, 3805)
# +===========================================+
# Joint 4 (15, 3805)
# +===========================================+
# Joint 5 (18, 3805)
# +===========================================+
# Joint 6 (21, 3805)
# +===========================================+
# Joint 7 (24, 3805)
# +===========================================+
# Joint 8 (27, 3805)
# +===========================================+
# Joint 9 (30, 3805)
# +===========================================+
# Joint 10 (33, 3805)
# +===========================================+
# Joint 11 (36, 3805)
# +===========================================+
# Joint 12 (39, 3805)
# +===========================================+
# Joint 13 (42, 3805)
# +===========================================+
# Joint 14 (45, 3805)
# +===========================================+
# Joint 15 (48, 3805)
# Key: 11
# +===========================================+
# +===========================================+
# Joint 1 (6, 3805)
# +===========================================+
# Joint 2 (9, 3805)
# +===========================================+
# Joint 3 (12, 3805)
# +===========================================+
# Joint 4 (15, 3805)
# +===========================================+
# Joint 5 (18, 3805)
# +===========================================+
# Joint 6 (21, 3805)
# +===========================================+
# Joint 7 (24, 3805)
# +===========================================+
# Joint 8 (27, 3805)
# +===========================================+
# Joint 9 (30, 3805)
# +===========================================+
# Joint 10 (33, 3805)
# +===========================================+
# Joint 11 (36, 3805)
# +===========================================+
# Joint 12 (39, 3805)
# +===========================================+
# Joint 13 (42, 3805)
# +===========================================+
# Joint 14 (45, 3805)
# +===========================================+
# Joint 15 (48, 3805)
# Key: 12
# +===========================================+
# +===========================================+
# Joint 1 (6, 3805)
# +===========================================+
# Joint 2 (9, 3805)
# +===========================================+
# Joint 3 (12, 3805)
# +===========================================+
# Joint 4 (15, 3805)
# +===========================================+
# Joint 5 (18, 3805)
# +===========================================+
# Joint 6 (21, 3805)
# +===========================================+
# Joint 7 (24, 3805)
# +===========================================+
# Joint 8 (27, 3805)
# +===========================================+
# Joint 9 (30, 3805)
# +===========================================+
# Joint 10 (33, 3805)
# +===========================================+
# Joint 11 (36, 3805)
# +===========================================+
# Joint 12 (39, 3805)
# +===========================================+
# Joint 13 (42, 3805)
# +===========================================+
# Joint 14 (45, 3805)
# +===========================================+
# Joint 15 (48, 3805)
# Key: 13
# +===========================================+
# +===========================================+
# Joint 1 (6, 3852)
# +===========================================+
# Joint 2 (9, 3852)
# +===========================================+
# Joint 3 (12, 3852)
# +===========================================+
# Joint 4 (15, 3852)
# +===========================================+
# Joint 5 (18, 3852)
# +===========================================+
# Joint 6 (21, 3852)
# +===========================================+
# Joint 7 (24, 3852)
# +===========================================+
# Joint 8 (27, 3852)
# +===========================================+
# Joint 9 (30, 3852)
# +===========================================+
# Joint 10 (33, 3852)
# +===========================================+
# Joint 11 (36, 3852)
# +===========================================+
# Joint 12 (39, 3852)
# +===========================================+
# Joint 13 (42, 3852)
# +===========================================+
# Joint 14 (45, 3852)
# +===========================================+
# Joint 15 (48, 3852)
# Key: 14
# +===========================================+
# +===========================================+
# Joint 1 (6, 3852)
# +===========================================+
# Joint 2 (9, 3852)
# +===========================================+
# Joint 3 (12, 3852)
# +===========================================+
# Joint 4 (15, 3852)
# +===========================================+
# Joint 5 (18, 3852)
# +===========================================+
# Joint 6 (21, 3852)
# +===========================================+
# Joint 7 (24, 3852)
# +===========================================+
# Joint 8 (27, 3852)
# +===========================================+
# Joint 9 (30, 3852)
# +===========================================+
# Joint 10 (33, 3852)
# +===========================================+
# Joint 11 (36, 3852)
# +===========================================+
# Joint 12 (39, 3852)
# +===========================================+
# Joint 13 (42, 3852)
# +===========================================+
# Joint 14 (45, 3852)
# +===========================================+
# Joint 15 (48, 3852)
# Key: 15
# +===========================================+
# +===========================================+
# Joint 1 (6, 3852)
# +===========================================+
# Joint 2 (9, 3852)
# +===========================================+
# Joint 3 (12, 3852)
# +===========================================+
# Joint 4 (15, 3852)
# +===========================================+
# Joint 5 (18, 3852)
# +===========================================+
# Joint 6 (21, 3852)
# +===========================================+
# Joint 7 (24, 3852)
# +===========================================+
# Joint 8 (27, 3852)
# +===========================================+
# Joint 9 (30, 3852)
# +===========================================+
# Joint 10 (33, 3852)
# +===========================================+
# Joint 11 (36, 3852)
# +===========================================+
# Joint 12 (39, 3852)
# +===========================================+
# Joint 13 (42, 3852)
# +===========================================+
# Joint 14 (45, 3852)
# +===========================================+
# Joint 15 (48, 3852)
# Key: 16
# +===========================================+
# +===========================================+
# Joint 1 (6, 3852)
# +===========================================+
# Joint 2 (9, 3852)
# +===========================================+
# Joint 3 (12, 3852)
# +===========================================+
# Joint 4 (15, 3852)
# +===========================================+
# Joint 5 (18, 3852)
# +===========================================+
# Joint 6 (21, 3852)
# +===========================================+
# Joint 7 (24, 3852)
# +===========================================+
# Joint 8 (27, 3852)
# +===========================================+
# Joint 9 (30, 3852)
# +===========================================+
# Joint 10 (33, 3852)
# +===========================================+
# Joint 11 (36, 3852)
# +===========================================+
# Joint 12 (39, 3852)
# +===========================================+
# Joint 13 (42, 3852)
# +===========================================+
# Joint 14 (45, 3852)
# +===========================================+
# Joint 15 (48, 3852)
# Key: 17
# +===========================================+
# +===========================================+
# Joint 1 (6, 2357)
# +===========================================+
# Joint 2 (9, 2357)
# +===========================================+
# Joint 3 (12, 2357)
# +===========================================+
# Joint 4 (15, 2357)
# +===========================================+
# Joint 5 (18, 2357)
# +===========================================+
# Joint 6 (21, 2357)
# +===========================================+
# Joint 7 (24, 2357)
# +===========================================+
# Joint 8 (27, 2357)
# +===========================================+
# Joint 9 (30, 2357)
# +===========================================+
# Joint 10 (33, 2357)
# +===========================================+
# Joint 11 (36, 2357)
# +===========================================+
# Joint 12 (39, 2357)
# +===========================================+
# Joint 13 (42, 2357)
# +===========================================+
# Joint 14 (45, 2357)
# +===========================================+
# Joint 15 (48, 2357)
# Key: 18
# +===========================================+
# +===========================================+
# Joint 1 (6, 2357)
# +===========================================+
# Joint 2 (9, 2357)
# +===========================================+
# Joint 3 (12, 2357)
# +===========================================+
# Joint 4 (15, 2357)
# +===========================================+
# Joint 5 (18, 2357)
# +===========================================+
# Joint 6 (21, 2357)
# +===========================================+
# Joint 7 (24, 2357)
# +===========================================+
# Joint 8 (27, 2357)
# +===========================================+
# Joint 9 (30, 2357)
# +===========================================+
# Joint 10 (33, 2357)
# +===========================================+
# Joint 11 (36, 2357)
# +===========================================+
# Joint 12 (39, 2357)
# +===========================================+
# Joint 13 (42, 2357)
# +===========================================+
# Joint 14 (45, 2357)
# +===========================================+
# Joint 15 (48, 2357)
# Key: 19
# +===========================================+
# +===========================================+
# Joint 1 (6, 2357)
# +===========================================+
# Joint 2 (9, 2357)
# +===========================================+
# Joint 3 (12, 2357)
# +===========================================+
# Joint 4 (15, 2357)
# +===========================================+
# Joint 5 (18, 2357)
# +===========================================+
# Joint 6 (21, 2357)
# +===========================================+
# Joint 7 (24, 2357)
# +===========================================+
# Joint 8 (27, 2357)
# +===========================================+
# Joint 9 (30, 2357)
# +===========================================+
# Joint 10 (33, 2357)
# +===========================================+
# Joint 11 (36, 2357)
# +===========================================+
# Joint 12 (39, 2357)
# +===========================================+
# Joint 13 (42, 2357)
# +===========================================+
# Joint 14 (45, 2357)
# +===========================================+
# Joint 15 (48, 2357)
# Key: 20
# +===========================================+
# +===========================================+
# Joint 1 (6, 2357)
# +===========================================+
# Joint 2 (9, 2357)
# +===========================================+
# Joint 3 (12, 2357)
# +===========================================+
# Joint 4 (15, 2357)
# +===========================================+
# Joint 5 (18, 2357)
# +===========================================+
# Joint 6 (21, 2357)
# +===========================================+
# Joint 7 (24, 2357)
# +===========================================+
# Joint 8 (27, 2357)
# +===========================================+
# Joint 9 (30, 2357)
# +===========================================+
# Joint 10 (33, 2357)
# +===========================================+
# Joint 11 (36, 2357)
# +===========================================+
# Joint 12 (39, 2357)
# +===========================================+
# Joint 13 (42, 2357)
# +===========================================+
# Joint 14 (45, 2357)
# +===========================================+
# Joint 15 (48, 2357)
# Key: 21
# +===========================================+
# +===========================================+
# Joint 1 (6, 2721)
# +===========================================+
# Joint 2 (9, 2721)
# +===========================================+
# Joint 3 (12, 2721)
# +===========================================+
# Joint 4 (15, 2721)
# +===========================================+
# Joint 5 (18, 2721)
# +===========================================+
# Joint 6 (21, 2721)
# +===========================================+
# Joint 7 (24, 2721)
# +===========================================+
# Joint 8 (27, 2721)
# +===========================================+
# Joint 9 (30, 2721)
# +===========================================+
# Joint 10 (33, 2721)
# +===========================================+
# Joint 11 (36, 2721)
# +===========================================+
# Joint 12 (39, 2721)
# +===========================================+
# Joint 13 (42, 2721)
# +===========================================+
# Joint 14 (45, 2721)
# +===========================================+
# Joint 15 (48, 2721)
# Key: 22
# +===========================================+
# +===========================================+
# Joint 1 (6, 2721)
# +===========================================+
# Joint 2 (9, 2721)
# +===========================================+
# Joint 3 (12, 2721)
# +===========================================+
# Joint 4 (15, 2721)
# +===========================================+
# Joint 5 (18, 2721)
# +===========================================+
# Joint 6 (21, 2721)
# +===========================================+
# Joint 7 (24, 2721)
# +===========================================+
# Joint 8 (27, 2721)
# +===========================================+
# Joint 9 (30, 2721)
# +===========================================+
# Joint 10 (33, 2721)
# +===========================================+
# Joint 11 (36, 2721)
# +===========================================+
# Joint 12 (39, 2721)
# +===========================================+
# Joint 13 (42, 2721)
# +===========================================+
# Joint 14 (45, 2721)
# +===========================================+
# Joint 15 (48, 2721)
# Key: 23
# +===========================================+
# +===========================================+
# Joint 1 (6, 2721)
# +===========================================+
# Joint 2 (9, 2721)
# +===========================================+
# Joint 3 (12, 2721)
# +===========================================+
# Joint 4 (15, 2721)
# +===========================================+
# Joint 5 (18, 2721)
# +===========================================+
# Joint 6 (21, 2721)
# +===========================================+
# Joint 7 (24, 2721)
# +===========================================+
# Joint 8 (27, 2721)
# +===========================================+
# Joint 9 (30, 2721)
# +===========================================+
# Joint 10 (33, 2721)
# +===========================================+
# Joint 11 (36, 2721)
# +===========================================+
# Joint 12 (39, 2721)
# +===========================================+
# Joint 13 (42, 2721)
# +===========================================+
# Joint 14 (45, 2721)
# +===========================================+
# Joint 15 (48, 2721)
# Key: 24
# +===========================================+
# +===========================================+
# Joint 1 (6, 2721)
# +===========================================+
# Joint 2 (9, 2721)
# +===========================================+
# Joint 3 (12, 2721)
# +===========================================+
# Joint 4 (15, 2721)
# +===========================================+
# Joint 5 (18, 2721)
# +===========================================+
# Joint 6 (21, 2721)
# +===========================================+
# Joint 7 (24, 2721)
# +===========================================+
# Joint 8 (27, 2721)
# +===========================================+
# Joint 9 (30, 2721)
# +===========================================+
# Joint 10 (33, 2721)
# +===========================================+
# Joint 11 (36, 2721)
# +===========================================+
# Joint 12 (39, 2721)
# +===========================================+
# Joint 13 (42, 2721)
# +===========================================+
# Joint 14 (45, 2721)
# +===========================================+
# Joint 15 (48, 2721)
# Key: 25
# +===========================================+
# +===========================================+
# Joint 1 (6, 1265)
# +===========================================+
# Joint 2 (9, 1265)
# +===========================================+
# Joint 3 (12, 1265)
# +===========================================+
# Joint 4 (15, 1265)
# +===========================================+
# Joint 5 (18, 1265)
# +===========================================+
# Joint 6 (21, 1265)
# +===========================================+
# Joint 7 (24, 1265)
# +===========================================+
# Joint 8 (27, 1265)
# +===========================================+
# Joint 9 (30, 1265)
# +===========================================+
# Joint 10 (33, 1265)
# +===========================================+
# Joint 11 (36, 1265)
# +===========================================+
# Joint 12 (39, 1265)
# +===========================================+
# Joint 13 (42, 1265)
# +===========================================+
# Joint 14 (45, 1265)
# +===========================================+
# Joint 15 (48, 1265)
# Key: 26
# +===========================================+
# +===========================================+
# Joint 1 (6, 1265)
# +===========================================+
# Joint 2 (9, 1265)
# +===========================================+
# Joint 3 (12, 1265)
# +===========================================+
# Joint 4 (15, 1265)
# +===========================================+
# Joint 5 (18, 1265)
# +===========================================+
# Joint 6 (21, 1265)
# +===========================================+
# Joint 7 (24, 1265)
# +===========================================+
# Joint 8 (27, 1265)
# +===========================================+
# Joint 9 (30, 1265)
# +===========================================+
# Joint 10 (33, 1265)
# +===========================================+
# Joint 11 (36, 1265)
# +===========================================+
# Joint 12 (39, 1265)
# +===========================================+
# Joint 13 (42, 1265)
# +===========================================+
# Joint 14 (45, 1265)
# +===========================================+
# Joint 15 (48, 1265)
# Key: 27
# +===========================================+
# +===========================================+
# Joint 1 (6, 1265)
# +===========================================+
# Joint 2 (9, 1265)
# +===========================================+
# Joint 3 (12, 1265)
# +===========================================+
# Joint 4 (15, 1265)
# +===========================================+
# Joint 5 (18, 1265)
# +===========================================+
# Joint 6 (21, 1265)
# +===========================================+
# Joint 7 (24, 1265)
# +===========================================+
# Joint 8 (27, 1265)
# +===========================================+
# Joint 9 (30, 1265)
# +===========================================+
# Joint 10 (33, 1265)
# +===========================================+
# Joint 11 (36, 1265)
# +===========================================+
# Joint 12 (39, 1265)
# +===========================================+
# Joint 13 (42, 1265)
# +===========================================+
# Joint 14 (45, 1265)
# +===========================================+
# Joint 15 (48, 1265)
# Key: 28
# +===========================================+
# +===========================================+
# Joint 1 (6, 1265)
# +===========================================+
# Joint 2 (9, 1265)
# +===========================================+
# Joint 3 (12, 1265)
# +===========================================+
# Joint 4 (15, 1265)
# +===========================================+
# Joint 5 (18, 1265)
# +===========================================+
# Joint 6 (21, 1265)
# +===========================================+
# Joint 7 (24, 1265)
# +===========================================+
# Joint 8 (27, 1265)
# +===========================================+
# Joint 9 (30, 1265)
# +===========================================+
# Joint 10 (33, 1265)
# +===========================================+
# Joint 11 (36, 1265)
# +===========================================+
# Joint 12 (39, 1265)
# +===========================================+
# Joint 13 (42, 1265)
# +===========================================+
# Joint 14 (45, 1265)
# +===========================================+
# Joint 15 (48, 1265)
# Key: 29
# +===========================================+
# +===========================================+
# Joint 1 (6, 1149)
# +===========================================+
# Joint 2 (9, 1149)
# +===========================================+
# Joint 3 (12, 1149)
# +===========================================+
# Joint 4 (15, 1149)
# +===========================================+
# Joint 5 (18, 1149)
# +===========================================+
# Joint 6 (21, 1149)
# +===========================================+
# Joint 7 (24, 1149)
# +===========================================+
# Joint 8 (27, 1149)
# +===========================================+
# Joint 9 (30, 1149)
# +===========================================+
# Joint 10 (33, 1149)
# +===========================================+
# Joint 11 (36, 1149)
# +===========================================+
# Joint 12 (39, 1149)
# +===========================================+
# Joint 13 (42, 1149)
# +===========================================+
# Joint 14 (45, 1149)
# +===========================================+
# Joint 15 (48, 1149)
# Key: 30
# +===========================================+
# +===========================================+
# Joint 1 (6, 1149)
# +===========================================+
# Joint 2 (9, 1149)
# +===========================================+
# Joint 3 (12, 1149)
# +===========================================+
# Joint 4 (15, 1149)
# +===========================================+
# Joint 5 (18, 1149)
# +===========================================+
# Joint 6 (21, 1149)
# +===========================================+
# Joint 7 (24, 1149)
# +===========================================+
# Joint 8 (27, 1149)
# +===========================================+
# Joint 9 (30, 1149)
# +===========================================+
# Joint 10 (33, 1149)
# +===========================================+
# Joint 11 (36, 1149)
# +===========================================+
# Joint 12 (39, 1149)
# +===========================================+
# Joint 13 (42, 1149)
# +===========================================+
# Joint 14 (45, 1149)
# +===========================================+
# Joint 15 (48, 1149)
# Key: 31
# +===========================================+
# +===========================================+
# Joint 1 (6, 1149)
# +===========================================+
# Joint 2 (9, 1149)
# +===========================================+
# Joint 3 (12, 1149)
# +===========================================+
# Joint 4 (15, 1149)
# +===========================================+
# Joint 5 (18, 1149)
# +===========================================+
# Joint 6 (21, 1149)
# +===========================================+
# Joint 7 (24, 1149)
# +===========================================+
# Joint 8 (27, 1149)
# +===========================================+
# Joint 9 (30, 1149)
# +===========================================+
# Joint 10 (33, 1149)
# +===========================================+
# Joint 11 (36, 1149)
# +===========================================+
# Joint 12 (39, 1149)
# +===========================================+
# Joint 13 (42, 1149)
# +===========================================+
# Joint 14 (45, 1149)
# +===========================================+
# Joint 15 (48, 1149)
# Key: 32
# +===========================================+
# +===========================================+
# Joint 1 (6, 1149)
# +===========================================+
# Joint 2 (9, 1149)
# +===========================================+
# Joint 3 (12, 1149)
# +===========================================+
# Joint 4 (15, 1149)
# +===========================================+
# Joint 5 (18, 1149)
# +===========================================+
# Joint 6 (21, 1149)
# +===========================================+
# Joint 7 (24, 1149)
# +===========================================+
# Joint 8 (27, 1149)
# +===========================================+
# Joint 9 (30, 1149)
# +===========================================+
# Joint 10 (33, 1149)
# +===========================================+
# Joint 11 (36, 1149)
# +===========================================+
# Joint 12 (39, 1149)
# +===========================================+
# Joint 13 (42, 1149)
# +===========================================+
# Joint 14 (45, 1149)
# +===========================================+
# Joint 15 (48, 1149)
# Key: 33
# +===========================================+
# +===========================================+
# Joint 1 (6, 2636)
# +===========================================+
# Joint 2 (9, 2636)
# +===========================================+
# Joint 3 (12, 2636)
# +===========================================+
# Joint 4 (15, 2636)
# +===========================================+
# Joint 5 (18, 2636)
# +===========================================+
# Joint 6 (21, 2636)
# +===========================================+
# Joint 7 (24, 2636)
# +===========================================+
# Joint 8 (27, 2636)
# +===========================================+
# Joint 9 (30, 2636)
# +===========================================+
# Joint 10 (33, 2636)
# +===========================================+
# Joint 11 (36, 2636)
# +===========================================+
# Joint 12 (39, 2636)
# +===========================================+
# Joint 13 (42, 2636)
# +===========================================+
# Joint 14 (45, 2636)
# +===========================================+
# Joint 15 (48, 2636)
# Key: 34
# +===========================================+
# +===========================================+
# Joint 1 (6, 2636)
# +===========================================+
# Joint 2 (9, 2636)
# +===========================================+
# Joint 3 (12, 2636)
# +===========================================+
# Joint 4 (15, 2636)
# +===========================================+
# Joint 5 (18, 2636)
# +===========================================+
# Joint 6 (21, 2636)
# +===========================================+
# Joint 7 (24, 2636)
# +===========================================+
# Joint 8 (27, 2636)
# +===========================================+
# Joint 9 (30, 2636)
# +===========================================+
# Joint 10 (33, 2636)
# +===========================================+
# Joint 11 (36, 2636)
# +===========================================+
# Joint 12 (39, 2636)
# +===========================================+
# Joint 13 (42, 2636)
# +===========================================+
# Joint 14 (45, 2636)
# +===========================================+
# Joint 15 (48, 2636)
# Key: 35
# +===========================================+
# +===========================================+
# Joint 1 (6, 2636)
# +===========================================+
# Joint 2 (9, 2636)
# +===========================================+
# Joint 3 (12, 2636)
# +===========================================+
# Joint 4 (15, 2636)
# +===========================================+
# Joint 5 (18, 2636)
# +===========================================+
# Joint 6 (21, 2636)
# +===========================================+
# Joint 7 (24, 2636)
# +===========================================+
# Joint 8 (27, 2636)
# +===========================================+
# Joint 9 (30, 2636)
# +===========================================+
# Joint 10 (33, 2636)
# +===========================================+
# Joint 11 (36, 2636)
# +===========================================+
# Joint 12 (39, 2636)
# +===========================================+
# Joint 13 (42, 2636)
# +===========================================+
# Joint 14 (45, 2636)
# +===========================================+
# Joint 15 (48, 2636)
# Key: 36
# +===========================================+
# +===========================================+
# Joint 1 (6, 2636)
# +===========================================+
# Joint 2 (9, 2636)
# +===========================================+
# Joint 3 (12, 2636)
# +===========================================+
# Joint 4 (15, 2636)
# +===========================================+
# Joint 5 (18, 2636)
# +===========================================+
# Joint 6 (21, 2636)
# +===========================================+
# Joint 7 (24, 2636)
# +===========================================+
# Joint 8 (27, 2636)
# +===========================================+
# Joint 9 (30, 2636)
# +===========================================+
# Joint 10 (33, 2636)
# +===========================================+
# Joint 11 (36, 2636)
# +===========================================+
# Joint 12 (39, 2636)
# +===========================================+
# Joint 13 (42, 2636)
# +===========================================+
# Joint 14 (45, 2636)
# +===========================================+
# Joint 15 (48, 2636)
# Key: 37
# +===========================================+
# +===========================================+
# Joint 1 (6, 2266)
# +===========================================+
# Joint 2 (9, 2266)
# +===========================================+
# Joint 3 (12, 2266)
# +===========================================+
# Joint 4 (15, 2266)
# +===========================================+
# Joint 5 (18, 2266)
# +===========================================+
# Joint 6 (21, 2266)
# +===========================================+
# Joint 7 (24, 2266)
# +===========================================+
# Joint 8 (27, 2266)
# +===========================================+
# Joint 9 (30, 2266)
# +===========================================+
# Joint 10 (33, 2266)
# +===========================================+
# Joint 11 (36, 2266)
# +===========================================+
# Joint 12 (39, 2266)
# +===========================================+
# Joint 13 (42, 2266)
# +===========================================+
# Joint 14 (45, 2266)
# +===========================================+
# Joint 15 (48, 2266)
# Key: 38
# +===========================================+
# +===========================================+
# Joint 1 (6, 2266)
# +===========================================+
# Joint 2 (9, 2266)
# +===========================================+
# Joint 3 (12, 2266)
# +===========================================+
# Joint 4 (15, 2266)
# +===========================================+
# Joint 5 (18, 2266)
# +===========================================+
# Joint 6 (21, 2266)
# +===========================================+
# Joint 7 (24, 2266)
# +===========================================+
# Joint 8 (27, 2266)
# +===========================================+
# Joint 9 (30, 2266)
# +===========================================+
# Joint 10 (33, 2266)
# +===========================================+
# Joint 11 (36, 2266)
# +===========================================+
# Joint 12 (39, 2266)
# +===========================================+
# Joint 13 (42, 2266)
# +===========================================+
# Joint 14 (45, 2266)
# +===========================================+
# Joint 15 (48, 2266)
# Key: 39
# +===========================================+
# +===========================================+
# Joint 1 (6, 2266)
# +===========================================+
# Joint 2 (9, 2266)
# +===========================================+
# Joint 3 (12, 2266)
# +===========================================+
# Joint 4 (15, 2266)
# +===========================================+
# Joint 5 (18, 2266)
# +===========================================+
# Joint 6 (21, 2266)
# +===========================================+
# Joint 7 (24, 2266)
# +===========================================+
# Joint 8 (27, 2266)
# +===========================================+
# Joint 9 (30, 2266)
# +===========================================+
# Joint 10 (33, 2266)
# +===========================================+
# Joint 11 (36, 2266)
# +===========================================+
# Joint 12 (39, 2266)
# +===========================================+
# Joint 13 (42, 2266)
# +===========================================+
# Joint 14 (45, 2266)
# +===========================================+
# Joint 15 (48, 2266)
# Key: 40
# +===========================================+
# +===========================================+
# Joint 1 (6, 2266)
# +===========================================+
# Joint 2 (9, 2266)
# +===========================================+
# Joint 3 (12, 2266)
# +===========================================+
# Joint 4 (15, 2266)
# +===========================================+
# Joint 5 (18, 2266)
# +===========================================+
# Joint 6 (21, 2266)
# +===========================================+
# Joint 7 (24, 2266)
# +===========================================+
# Joint 8 (27, 2266)
# +===========================================+
# Joint 9 (30, 2266)
# +===========================================+
# Joint 10 (33, 2266)
# +===========================================+
# Joint 11 (36, 2266)
# +===========================================+
# Joint 12 (39, 2266)
# +===========================================+
# Joint 13 (42, 2266)
# +===========================================+
# Joint 14 (45, 2266)
# +===========================================+
# Joint 15 (48, 2266)

# %%
## Plotting the results (tentetive)
# complete this
fig = plt.figure(figsize=(10,8))
plt.plot(noisy_stat, label = 'MSE - Noisy data')
plt.plot(recovered_stat, label = 'MSE - Recovered data')
plt.ylabel('MSE')
plt.legend()

# %% [markdown]
# ## Submission guidelines
# ---
# Extract the downloaded .zip file to a folder of your preference. The input and output paths are predefined and **DO NOT** change them, (we assume that 'Surname_Givenname_SBUID_hw6' is your working directory, and all the paths are relative to this directory).  The image read and write functions are already written for you. All you need to do is to fill in the blanks as indicated to generate proper outputs. **DO NOT** zip and upload the dataset on blackboard due to size limit.
#
# When submitting your .zip file through blackboard, please
# -- name your .zip file as **Surname_Givenname_SBUID_hw*.zip**.
#
# This zip file should include:
# ```
# Surname_Givenname_SBUID_hw*
#         |---Surname_Givenname_SBUID_hw*.ipynb
#         |---Surname_Givenname_SBUID_hw*.py
# ```
# where Surname_Givenname_SBUID_hw*.py is the Python code of Surname_Givenname_SBUID_hw*.ipynb, which can be dowloaded by File->Download .py.
#
# For instance, student Michael Jordan should submit a zip file named "Jordan_Michael_111134567_hw6.zip" for homework6 in this structure:
# ```
# Jordan_Michael_111134567_hw6
#         |---Jordan_Michael_111134567_hw6.ipynb
#         |---Jordan_Michael_111134567_hw6.py
# ```
#
# The **Surname_Givenname_SBUID_hw*.pdf** should include a **google shared link**. To generate the **google shared link**, first create a folder named **Surname_Givenname_SBUID_hw*** in your Google Drive with your Stony Brook account. The structure of the files in the folder should be exactly the same as the one you downloaded. If you alter the folder structures, the grading of your homework will be significantly delayed and possibly penalized.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter two TA's emails: ***bo.cao.1@stonybrook.edu*** and ***sayontan.ghosh@stonybrook.edu***. Make sure that TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box.
#
# Colab has a good feature of version control, you should take advantage of this to save your work properly. However, the timestamp of the submission made in blackboard is the only one that we consider for grading. To be more specific, we will only grade the version of your code right before the timestamp of the submission made in blackboard.
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be dealys in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
#
# **Late submission penalty:** <br>
# There will be a 10% penalty per day for late submission. However, you will have 4 days throughout the whole semester to submit late without penalty. Note that the grace period is calculated by days instead of hours. If you submit the homework one minute after the deadline, one late day will be counted. Likewise, if you submit one minute after the deadline, the 10% penaly will be imposed if not using the grace period.

# %% [markdown]
# # References
# [1] J. Martinez, R. Hossain, J. Romero, and J. J. Little, “A simple yet effective baseline for 3d human pose
# estimation,” in ICCV, 2017.

# %% [markdown]
# <!--Write your report here in markdown or html-->
